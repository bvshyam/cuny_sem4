# %%
import nltk
import numpy as np

# %%
nested = [[]] * 3

# %%
id(nested[1])
# Out:
# 156464776

# %%
import random
random.choice(np.arange(0,5))
# Out:
# 0

# %%
np.arange(0,5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
sent = ['No', 'good', 'fish', 'goes', 'anywhere', 'without', 'a', 'porpoise', '.']

# %%
all(len(w) > 4 for w in sent)
# Out:
# False

# %%
(len(w) > 4 for w in sent)
# Out:
# <generator object <genexpr> at 0x00000000095BED00>

# %%
>>> words = ['I', 'turned', 'off', 'the', 'spectroroute']
>>> tags = ['noun', 'verb', 'prep', 'det', 'noun']
>>> zips = zip(words, tags)

# %%
list(zips)
# Out:
# [('I', 'noun'),
#  ('turned', 'verb'),
#  ('off', 'prep'),
#  ('the', 'det'),
#  ('spectroroute', 'noun')]

# %%
>>> words = 'I turned off the spectroroute'.split()
>>> wordlens = [(len(word), word) for word in words]
>>> wordlens.sort()

# %%
wordlens
# Out:
# [(1, 'I'), (3, 'off'), (3, 'the'), (6, 'turned'), (12, 'spectroroute')]

# %%
>>> lexicon =  (('the', 'det', ['Di:', 'D@']), ('off', 'prep', ['Qf', 'O:f']) )
>>> lexicon.sort()
>>> lexicon[1] = ('turned', 'VBD', ['t3:nd', 't3`nd'])
>>> del lexicon[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-537a2412fab9> in <module>()
#       2 lexicon =  (('the', 'det', ['Di:', 'D@']), ('off', 'prep', ['Qf', 'O:f']) )
#       3 #>>> lexicon.sort()
# ----> 4 lexicon[1] = ('turned', 'VBD', ['t3:nd', 't3`nd'])
#       5 del lexicon[0]
#
# TypeError: 'tuple' object does not support item assignment

# %%
lexicon
# Out:
# [('turned', 'VBD', ['t3:nd', 't3`nd'])]

# %%
>>> sent = ['The', 'dog', 'gave', 'John', 'the', 'newspaper']
>>> n = 3
>>> [sent[i:i+n] for i in range(len(sent)-n+1)]
# Out:
# [['The', 'dog', 'gave'],
#  ['dog', 'gave', 'John'],
#  ['gave', 'John', 'the'],
#  ['John', 'the', 'newspaper']]

# %%
range(len(sent)-n+1)
# Out:
# range(0, 4)

# %%
import pprint

# %%
>>> m, n = 3, 7
>>> array = [[set() for i in range(n)] for j in range(m)]
>>> array[2][5].add('Alice')
>>> pprint.pprint(array)
# Out:
# [[set(), set(), set(), set(), set(), set(), set()],
#  [set(), set(), set(), set(), set(), set(), set()],
#  [set(), set(), set(), set(), set(), {'Alice'}, set()]]

# %%
[[set() for i in range(n)] for j in range(m)]
# Out:
# [[set(), set(), set(), set(), set(), set(), set()],
#  [set(), set(), set(), set(), set(), set(), set()],
#  [set(), set(), set(), set(), set(), set(), set()]]

# %%
6-4
# Out:
# 2

# %%
def permutations(seq):
    if len(seq) <= 1:
        yield seq
    else:
        for perm in permutations(seq[1:]):
            print(perm)
            for i in range(len(perm)+1):
                yield perm[:i] + seq[0:1] + perm[i:]
                
list(permutations(['police', 'fish', 'buffalo']))
# Out:
# ['buffalo']
# ['fish', 'buffalo']
# ['buffalo', 'fish']
# [['police', 'fish', 'buffalo'],
#  ['fish', 'police', 'buffalo'],
#  ['fish', 'buffalo', 'police'],
#  ['police', 'buffalo', 'fish'],
#  ['buffalo', 'police', 'fish'],
#  ['buffalo', 'fish', 'police']]

# %%
from itertools import permutations

# %%
list(permutations(['police', 'fish', 'buffalo']))
# Out:
# [('police', 'fish', 'buffalo'),
#  ('police', 'buffalo', 'fish'),
#  ('fish', 'police', 'buffalo'),
#  ('fish', 'buffalo', 'police'),
#  ('buffalo', 'police', 'fish'),
#  ('buffalo', 'fish', 'police')]

# %%
lengths = list(map(len, ['Take', 'care', 'sense', 'sounds', 'take', 'care', 'themselves']))

# %%
sum(lengths)/len(lengths)
# Out:
# 5.285714285714286

# %%
song = [['four', 'calling', 'birds'], ['three', 'French', 'hens'], ['two', 'turtle', 'doves']]

# %%
song[0]
# Out:
# ['four', 'calling', 'birds']

# %%
list(zip(*song))
# Out:
# [('four', 'three', 'two'),
#  ('calling', 'French', 'turtle'),
#  ('birds', 'hens', 'doves')]

# %%
nltk.metrics.__file__
# Out:
# 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\nltk\\translate\\metrics.py'

# %%
def find_words(text, wordlength, result=[]):
    for word in text:
        if len(word) == wordlength:
            result.append(word)
    return result

# %%
>>> import pdb
>>> find_words(['cat'], 3)
# Out:
# ['cat']

# %%
pdb.run("find_words(['dog'], 3)")
# Out:
# > <string>(1)<module>()->None
# (Pdb) s
# --Call--
# > <ipython-input-90-c8bbf12fcbb5>(1)find_words()
# -> def find_words(text, wordlength, result=[]):
# (Pdb) s
# > <ipython-input-90-c8bbf12fcbb5>(2)find_words()
# -> for word in text:
# (Pdb) args
# text = ['dog']
# wordlength = 3
# result = ['cat', 'dog', 'dog', 'dog']
# (Pdb) s
# > <ipython-input-90-c8bbf12fcbb5>(3)find_words()
# -> if len(word) == wordlength:
# (Pdb) args
# text = ['dog']
# wordlength = 3
# result = ['cat', 'dog', 'dog', 'dog']
# (Pdb) parm
# *** NameError: name 'parm' is not defined
# (Pdb) param
# *** NameError: name 'param' is not defined
# (Pdb) step
# > <ipython-input-90-c8bbf12fcbb5>(4)find_words()
# -> result.append(word)
# (Pdb) S
# *** NameError: name 'S' is not defined
# (Pdb) s
# > <ipython-input-90-c8bbf12fcbb5>(2)find_words()
# -> for word in text:
# (Pdb) s
# > <ipython-input-90-c8bbf12fcbb5>(5)find_words()
# -> return result
# (Pdb) args
# text = ['dog']
# wordlength = 3
# ...

# %%
def factorial(n):
    """Return the factorial of n, an exact integer >= 0.

    >>> [factorial(n) for n in range(6)]
    [1, 1, 2, 6, 24, 120]
    >>> factorial(30)
    265252859812191058636308480000000
    >>> factorial(-1)
    Traceback (most recent call last):
        ...
    ValueError: n must be >= 0

    Factorials of floats are OK, but the float must be an exact integer:
    >>> factorial(30.1)
    Traceback (most recent call last):
        ...
    ValueError: n must be exact integer
    >>> factorial(30.0)
    265252859812191058636308480000000

    It must also not be ridiculously large:
    >>> factorial(1e100)
    Traceback (most recent call last):
        ...
    OverflowError: n too large
    """

    import math
    if not n >= 0:
        raise ValueError("n must be >= 0")
    if math.floor(n) != n:
        raise ValueError("n must be exact integer")
    if n+1 == n:  # catch a value like 1e300
        raise OverflowError("n too large")
    result = 1
    factor = 2
    while factor <= n:
        result *= factor
        factor += 1
    return result


if __name__ == "__main__":
    import doctest
    doctest.testmod()

# %%
def traverse(graph, start, node):
    graph.depth[node.name] = node.shortest_path_distance(start)
    for child in node.hyponyms():
        graph.add_edge(node.name, child.name)
        traverse(graph, start, child)
            
def hyponym_graph(start):
    G = nx.Graph()
    G.depth = {}
    traverse(G, start, start)
    return G
def graph_draw(graph):
    nx.draw_random(graph,    node_size = [16 * graph.degree(n) for n in graph], node_color = [graph.depth[n] for n in graph], with_labels = False)
    matplotlib.pyplot.show()

# %%
            >>> dog = wn.synset('dog.n.01')
            >>> graph = hyponym_graph(dog)
            >>> graph_draw(graph)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
import networkx as nx
import matplotlib
from nltk.corpus import wordnet as wn

# %%
wn.synset('dog.n.01').hyponyms()
# Out:
# [Synset('basenji.n.01'),
#  Synset('corgi.n.01'),
#  Synset('cur.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('griffon.n.02'),
#  Synset('hunting_dog.n.01'),
#  Synset('lapdog.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('newfoundland.n.01'),
#  Synset('pooch.n.01'),
#  Synset('poodle.n.01'),
#  Synset('pug.n.01'),
#  Synset('puppy.n.01'),
#  Synset('spitz.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('working_dog.n.01')]
