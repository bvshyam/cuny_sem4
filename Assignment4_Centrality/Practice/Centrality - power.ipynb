# %%
#!/usr/bin/env python
# encoding: utf-8
"""
LJ_fetch.py

Created by Maksim Tsvetovat on 2011-04-28.
Copyright (c) 2011 __MyCompanyName__. All rights reserved.
"""

import sys
import os
import networkx as net
import urllib


def read_lj_friends(g, name):
    # fetch the friend-list from LiveJournal
    response=urllib.urlopen('http://www.livejournal.com/misc/fdata.bml?user='+name)
    for line in response.readlines():
        #Comments in the response start with a '#'
        if line.startswith('#'): continue 
        
        # the format is "< name" (incoming) or "> name" (outgoing)
        parts=line.split()
        
        #make sure that we don't have an empty line
        if len(parts)==0: continue
        
        #add the edge to the network
        if parts[0]=='<': 
            g.add_edge(parts[1],name)
        else:
            g.add_edge(name,parts[1])

def snowball_sampling(g, center, max_depth=1, current_depth=0, taboo_list=[]):
    # if we have reached the depth limit of the search, bomb out.
    print center, current_depth, max_depth, taboo_list
    if current_depth==max_depth: 
        print 'out of depth'
        return taboo_list
    if center in taboo_list:
        print 'taboo' 
        return taboo_list #we've been here before
    else:
        taboo_list.append(center) # we shall never return
        
    read_lj_friends(g, center)
    
    for node in g.neighbors(center):
        taboo_list=snowball_sampling(g, node, current_depth=current_depth+1, max_depth=max_depth, taboo_list=taboo_list)
    
    return taboo_list
    
    







def main():
    g=net.Graph()
#    read_lj_friends(g,'kozel_na_sakse')
    snowball_sampling(g,'kozel_na_sakse')
    

if __name__ == '__main__':
    main()

# %%
import networkx as net
import urllib
import matplotlib.pyplot as plt

# %%
g=net.Graph()

# %%
g.add_edge('a','b')

# %%
g.add_edge('b','c')
g.add_edge('c','a')
net.draw(g,with_labels=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
g['a']['b']['weight']=1
g['a']['b']['weight']
# Out:
# 1

# %%
def read_lj_friends(g, name):
    # fetch the friend-list from LiveJournal
    response=urllib.request.urlopen('http://www.livejournal.com/misc/fdata.bml?user='+name)
    for line in response.readlines():
        line = str.replace(str(line),'b\'','')
        line = str.replace(line,'\\n\'','')
        #Comments in the response start with a '#'
        if line.startswith('#'): continue 
        
        # the format is "< name" (incoming) or "> name" (outgoing)
        parts=line.split()
        
        #make sure that we don't have an empty line
        if len(parts)==0: continue
        
        #add the edge to the network
        if parts[0]=='<': 
            #print(parts[1])
            g.add_edge(parts[1],name)
        elif parts[0]=='>':
            #print(parts[1])
            g.add_edge(name,parts[1])
        else:
            continue

# %%
g=net.Graph()
read_lj_friends(g,'valerois')
len(g) #count the number of nodes returned
# Out:
# 302

# %%
len(net.nodes(g))
# Out:
# 302

# %%
net.draw(g)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
response=urllib.request.urlopen('http://www.livejournal.com/misc/fdata.bml?user=valerois')
for line in response.readlines():
    #print(type(line))
    line = str.replace(str(line),'b\'','')
    print(line)
    print(line.split())
    #if line.startswith('b\'#'): 
    #    print(line)
# Out:
# # Note: Polite data miners cache on their end.  Impolite ones get banned.\n'
# ['#', 'Note:', 'Polite', 'data', 'miners', 'cache', 'on', 'their', 'end.', 'Impolite', 'ones', 'get', "banned.\\n'"]
# > bagira\n'
# ['>', "bagira\\n'"]
# > angerona\n'
# ['>', "angerona\\n'"]
# > yankel\n'
# ['>', "yankel\\n'"]
# > yelya\n'
# ['>', "yelya\\n'"]
# > ponka\n'
# ['>', "ponka\\n'"]
# > marinka\n'
# ['>', "marinka\\n'"]
# > saper\n'
# ['>', "saper\\n'"]
# > levinius\n'
# ['>', "levinius\\n'"]
# > monella\n'
# ['>', "monella\\n'"]
# > irbisa\n'
# ['>', "irbisa\\n'"]
# > innaplanetyanka\n'
# ['>', "innaplanetyanka\\n'"]
# > hutshepsut\n'
# ['>', "hutshepsut\\n'"]
# > skyg74\n'
# ['>', "skyg74\\n'"]
# > samoleg\n'
# ['>', "samoleg\\n'"]
# > actr\n'
# ['>', "actr\\n'"]
# > gottfrid\n'
# ['>', "gottfrid\\n'"]
# > krimsky\n'
# ['>', "krimsky\\n'"]
# > nelis\n'
# ['>', "nelis\\n'"]
# > ptfenix\n'
# ['>', "ptfenix\\n'"]
# > leprechaun\n'
# ['>', "leprechaun\\n'"]
# > a_u\n'
# ['>', "a_u\\n'"]
# > e_f\n'
# ['>', "e_f\\n'"]
# > boctok\n'
# ['>', "boctok\\n'"]
# > karial\n'
# ['>', "karial\\n'"]
# > wattson\n'
# ['>', "wattson\\n'"]
# > baryshnia\n'
# ['>', "baryshnia\\n'"]
# > ntl\n'
# ['>', "ntl\\n'"]
# > salamandrina_\n'
# ['>', "salamandrina_\\n'"]
# > ant_fugue\n'
# ['>', "ant_fugue\\n'"]
# > levik\n'
# ['>', "levik\\n'"]
# > _milashka\n'
# ['>', "_milashka\\n'"]
# > oonabond\n'
# ['>', "oonabond\\n'"]
# > alinaf\n'
# ['>', "alinaf\\n'"]
# > vollalol\n'
# ['>', "vollalol\\n'"]
# > kitobow\n'
# ['>', "kitobow\\n'"]
# > petitmari\n'
# ['>', "petitmari\\n'"]
# > babushonok\n'
# ['>', "babushonok\\n'"]
# > koniglio\n'
# ['>', "koniglio\\n'"]
# > berryl\n'
# ['>', "berryl\\n'"]
# > sylphida\n'
# ['>', "sylphida\\n'"]
# > graier\n'
# ['>', "graier\\n'"]
# > drunk_cherry\n'
# ['>', "drunk_cherry\\n'"]
# > mamaracha\n'
# ['>', "mamaracha\\n'"]
# > doc_a\n'
# ['>', "doc_a\\n'"]
# > 3eta\n'
# ['>', "3eta\\n'"]
# > togranada\n'
# ['>', "togranada\\n'"]
# > vorobeika\n'
# ['>', "vorobeika\\n'"]
# > mel_ny\n'
# ['>', "mel_ny\\n'"]
# > nicety\n'
# ['>', "nicety\\n'"]
# > elka_palka\n'
# ['>', "elka_palka\\n'"]
# > milady_winter\n'
# ['>', "milady_winter\\n'"]
# > lengo\n'
# ['>', "lengo\\n'"]
# > bengalia\n'
# ['>', "bengalia\\n'"]
# > stalic\n'
# ['>', "stalic\\n'"]
# > asyatka\n'
# ['>', "asyatka\\n'"]
# > kpoxa_e\n'
# ['>', "kpoxa_e\\n'"]
# > klaboo\n'
# ['>', "klaboo\\n'"]
# > azbukivedi\n'
# ['>', "azbukivedi\\n'"]
# > pavelrudnev\n'
# ['>', "pavelrudnev\\n'"]
# > vorodis\n'
# ['>', "vorodis\\n'"]
# > ranja\n'
# ['>', "ranja\\n'"]
# > kirulya\n'
# ['>', "kirulya\\n'"]
# > zlove\n'
# ['>', "zlove\\n'"]
# > charmel\n'
# ['>', "charmel\\n'"]
# > krolchatina\n'
# ['>', "krolchatina\\n'"]
# > glagolik\n'
# ['>', "glagolik\\n'"]
# > _arizonadream_\n'
# ['>', "_arizonadream_\\n'"]
# > kessil\n'
# ['>', "kessil\\n'"]
# > pandausa\n'
# ['>', "pandausa\\n'"]
# > sunnychka\n'
# ['>', "sunnychka\\n'"]
# > darwen\n'
# ['>', "darwen\\n'"]
# > sushile\n'
# ['>', "sushile\\n'"]
# > babkaezhka\n'
# ['>', "babkaezhka\\n'"]
# > snusmoomrik\n'
# ['>', "snusmoomrik\\n'"]
# > bills_daughter\n'
# ['>', "bills_daughter\\n'"]
# > cute_n_gorgeous\n'
# ['>', "cute_n_gorgeous\\n'"]
# > fomina\n'
# ['>', "fomina\\n'"]
# > zoe_dorogaya\n'
# ['>', "zoe_dorogaya\\n'"]
# > ortivika\n'
# ['>', "ortivika\\n'"]
# > kinoida\n'
# ['>', "kinoida\\n'"]
# > xenia\n'
# ['>', "xenia\\n'"]
# > greenarine\n'
# ['>', "greenarine\\n'"]
# > igmak\n'
# ['>', "igmak\\n'"]
# > elarbee\n'
# ['>', "elarbee\\n'"]
# > viks_vaporub\n'
# ['>', "viks_vaporub\\n'"]
# > new_finder\n'
# ['>', "new_finder\\n'"]
# > la_serafina\n'
# ['>', "la_serafina\\n'"]
# > fox_in_burrow\n'
# ['>', "fox_in_burrow\\n'"]
# > duisiya\n'
# ['>', "duisiya\\n'"]
# > janelight\n'
# ['>', "janelight\\n'"]
# > true_lady\n'
# ['>', "true_lady\\n'"]
# > tigra_usa\n'
# ['>', "tigra_usa\\n'"]
# > pripev0chka\n'
# ['>', "pripev0chka\\n'"]
# > sonbahar\n'
# ['>', "sonbahar\\n'"]
# > kolsanova\n'
# ['>', "kolsanova\\n'"]
# > darsik_dasha\n'
# ['>', "darsik_dasha\\n'"]
# > barma_glott\n'
# ['>', "barma_glott\\n'"]
# > ulybchivaya\n'
# ['>', "ulybchivaya\\n'"]
# > lgoldshm\n'
# ['>', "lgoldshm\\n'"]
# > polosatka\n'
# ['>', "polosatka\\n'"]
# > pinyusha\n'
# ['>', "pinyusha\\n'"]
# > angelight_a\n'
# ['>', "angelight_a\\n'"]
# > diefrau\n'
# ['>', "diefrau\\n'"]
# > amid1\n'
# ['>', "amid1\\n'"]
# > marina_paz\n'
# ['>', "marina_paz\\n'"]
# > mivak\n'
# ['>', "mivak\\n'"]
# > milaslj\n'
# ['>', "milaslj\\n'"]
# > postolenka\n'
# ['>', "postolenka\\n'"]
# > oreganum\n'
# ['>', "oreganum\\n'"]
# > natali_ya\n'
# ['>', "natali_ya\\n'"]
# > horn_blende\n'
# ['>', "horn_blende\\n'"]
# > taikaaa\n'
# ['>', "taikaaa\\n'"]
# > frenchrus\n'
# ['>', "frenchrus\\n'"]
# > ment52\n'
# ['>', "ment52\\n'"]
# > m_golightly\n'
# ['>', "m_golightly\\n'"]
# > rozetka_q\n'
# ['>', "rozetka_q\\n'"]
# > artavika\n'
# ['>', "artavika\\n'"]
# > olganovikova\n'
# ['>', "olganovikova\\n'"]
# > sol_tat\n'
# ['>', "sol_tat\\n'"]
# > nyctea_nivea\n'
# ['>', "nyctea_nivea\\n'"]
# > miaky_miaky\n'
# ['>', "miaky_miaky\\n'"]
# > vareni_k\n'
# ['>', "vareni_k\\n'"]
# > lerche_z\n'
# ['>', "lerche_z\\n'"]
# > yoreshet\n'
# ['>', "yoreshet\\n'"]
# > ms_lizzy_bennet\n'
# ['>', "ms_lizzy_bennet\\n'"]
# > nucamb_no_necky\n'
# ['>', "nucamb_no_necky\\n'"]
# > pavel_kosenko\n'
# ['>', "pavel_kosenko\\n'"]
# > tegaychik\n'
# ['>', "tegaychik\\n'"]
# > farbys\n'
# ['>', "farbys\\n'"]
# > dementievskiy\n'
# ['>', "dementievskiy\\n'"]
# > mykidsmom1\n'
# ['>', "mykidsmom1\\n'"]
# > f3\n'
# ['>', "f3\\n'"]
# > myppa\n'
# ['>', "myppa\\n'"]
# > vlada4ka\n'
# ['>', "vlada4ka\\n'"]
# > olialukoe\n'
# ['>', "olialukoe\\n'"]
# > maleficente\n'
# ['>', "maleficente\\n'"]
# > londonguide\n'
# ['>', "londonguide\\n'"]
# > zuka1\n'
# ['>', "zuka1\\n'"]
# > foxy_helen\n'
# ['>', "foxy_helen\\n'"]
# > ratitas\n'
# ['>', "ratitas\\n'"]
# > alisa_neverova\n'
# ['>', "alisa_neverova\\n'"]
# > le_milady\n'
# ['>', "le_milady\\n'"]
# > sanechka_blume\n'
# ['>', "sanechka_blume\\n'"]
# > red_garnet\n'
# ['>', "red_garnet\\n'"]
# > shpilenok\n'
# ['>', "shpilenok\\n'"]
# > bobcatik\n'
# ['>', "bobcatik\\n'"]
# > morseanen\n'
# ['>', "morseanen\\n'"]
# > wonder1ng\n'
# ['>', "wonder1ng\\n'"]
# > irenabar\n'
# ['>', "irenabar\\n'"]
# > tareeva\n'
# ['>', "tareeva\\n'"]
# > samsebeskazal\n'
# ['>', "samsebeskazal\\n'"]
# > grazdano4ka\n'
# ['>', "grazdano4ka\\n'"]
# > kristina_stark\n'
# ['>', "kristina_stark\\n'"]
# > marusia05\n'
# ['>', "marusia05\\n'"]
# > beautyartist\n'
# ['>', "beautyartist\\n'"]
# > kapturka\n'
# ['>', "kapturka\\n'"]
# > lolagetty\n'
# ['>', "lolagetty\\n'"]
# > milaanufrieva\n'
# ['>', "milaanufrieva\\n'"]
# > ksenia_vasil\n'
# ['>', "ksenia_vasil\\n'"]
# > borisakunin\n'
# ['>', "borisakunin\\n'"]
# > lisica_iz_sitca\n'
# ['>', "lisica_iz_sitca\\n'"]
# > leeloo5th\n'
# ['>', "leeloo5th\\n'"]
# > arinusik333\n'
# ['>', "arinusik333\\n'"]
# > krasivey\n'
# ['>', "krasivey\\n'"]
# > morena_morana\n'
# ['>', "morena_morana\\n'"]
# > lefortoff\n'
# ['>', "lefortoff\\n'"]
# > donna_marta\n'
# ['>', "donna_marta\\n'"]
# > agizatullina\n'
# ['>', "agizatullina\\n'"]
# > shshifter\n'
# ['>', "shshifter\\n'"]
# < bagira\n'
# ['<', "bagira\\n'"]
# < recoder\n'
# ['<', "recoder\\n'"]
# < angerona\n'
# ['<', "angerona\\n'"]
# < yankel\n'
# ['<', "yankel\\n'"]
# < yelya\n'
# ['<', "yelya\\n'"]
# < ponka\n'
# ['<', "ponka\\n'"]
# < marinka\n'
# ['<', "marinka\\n'"]
# < saper\n'
# ['<', "saper\\n'"]
# < levinius\n'
# ['<', "levinius\\n'"]
# < monella\n'
# ['<', "monella\\n'"]
# < irbisa\n'
# ['<', "irbisa\\n'"]
# < innaplanetyanka\n'
# ['<', "innaplanetyanka\\n'"]
# < hutshepsut\n'
# ['<', "hutshepsut\\n'"]
# < acya\n'
# ['<', "acya\\n'"]
# < skyg74\n'
# ['<', "skyg74\\n'"]
# < actr\n'
# ['<', "actr\\n'"]
# < opora\n'
# ['<', "opora\\n'"]
# < gottfrid\n'
# ['<', "gottfrid\\n'"]
# < krimsky\n'
# ['<', "krimsky\\n'"]
# < nelis\n'
# ['<', "nelis\\n'"]
# < ptfenix\n'
# ['<', "ptfenix\\n'"]
# < leprechaun\n'
# ['<', "leprechaun\\n'"]
# < a_u\n'
# ['<', "a_u\\n'"]
# < e_f\n'
# ['<', "e_f\\n'"]
# < boctok\n'
# ['<', "boctok\\n'"]
# < karial\n'
# ['<', "karial\\n'"]
# < baryshnia\n'
# ['<', "baryshnia\\n'"]
# < ntl\n'
# ['<', "ntl\\n'"]
# < salamandrina_\n'
# ['<', "salamandrina_\\n'"]
# < ant_fugue\n'
# ['<', "ant_fugue\\n'"]
# < _milashka\n'
# ['<', "_milashka\\n'"]
# < alinaf\n'
# ['<', "alinaf\\n'"]
# < owl98\n'
# ['<', "owl98\\n'"]
# < vollalol\n'
# ['<', "vollalol\\n'"]
# < petitmari\n'
# ['<', "petitmari\\n'"]
# < babushonok\n'
# ['<', "babushonok\\n'"]
# < koniglio\n'
# ['<', "koniglio\\n'"]
# < berryl\n'
# ['<', "berryl\\n'"]
# < sylphida\n'
# ['<', "sylphida\\n'"]
# < graier\n'
# ['<', "graier\\n'"]
# < drunk_cherry\n'
# ['<', "drunk_cherry\\n'"]
# < mamaracha\n'
# ['<', "mamaracha\\n'"]
# < staryiy\n'
# ['<', "staryiy\\n'"]
# < doc_a\n'
# ['<', "doc_a\\n'"]
# < 3eta\n'
# ['<', "3eta\\n'"]
# < togranada\n'
# ['<', "togranada\\n'"]
# < vorobeika\n'
# ['<', "vorobeika\\n'"]
# < mel_ny\n'
# ['<', "mel_ny\\n'"]
# < elka_palka\n'
# ['<', "elka_palka\\n'"]
# < kisverchik\n'
# ['<', "kisverchik\\n'"]
# < kozerojka\n'
# ['<', "kozerojka\\n'"]
# < milady_winter\n'
# ['<', "milady_winter\\n'"]
# < galephys\n'
# ['<', "galephys\\n'"]
# < lengo\n'
# ['<', "lengo\\n'"]
# < bengalia\n'
# ['<', "bengalia\\n'"]
# < asyatka\n'
# ['<', "asyatka\\n'"]
# < kpoxa_e\n'
# ['<', "kpoxa_e\\n'"]
# < klaboo\n'
# ['<', "klaboo\\n'"]
# < azbukivedi\n'
# ['<', "azbukivedi\\n'"]
# < vorodis\n'
# ['<', "vorodis\\n'"]
# < ranja\n'
# ['<', "ranja\\n'"]
# < eug3\n'
# ['<', "eug3\\n'"]
# < imur\n'
# ['<', "imur\\n'"]
# < yuksiyuksi\n'
# ['<', "yuksiyuksi\\n'"]
# < kirulya\n'
# ['<', "kirulya\\n'"]
# < charmel\n'
# ['<', "charmel\\n'"]
# < krolchatina\n'
# ['<', "krolchatina\\n'"]
# < ushkin\n'
# ['<', "ushkin\\n'"]
# < glagolik\n'
# ['<', "glagolik\\n'"]
# < _arizonadream_\n'
# ['<', "_arizonadream_\\n'"]
# < pandausa\n'
# ['<', "pandausa\\n'"]
# < sunnychka\n'
# ['<', "sunnychka\\n'"]
# < darwen\n'
# ['<', "darwen\\n'"]
# < sushile\n'
# ['<', "sushile\\n'"]
# < babkaezhka\n'
# ['<', "babkaezhka\\n'"]
# < snusmoomrik\n'
# ['<', "snusmoomrik\\n'"]
# < bills_daughter\n'
# ['<', "bills_daughter\\n'"]
# < cute_n_gorgeous\n'
# ['<', "cute_n_gorgeous\\n'"]
# < fomina\n'
# ['<', "fomina\\n'"]
# < zoe_dorogaya\n'
# ['<', "zoe_dorogaya\\n'"]
# < lian_lj\n'
# ['<', "lian_lj\\n'"]
# < ortivika\n'
# ['<', "ortivika\\n'"]
# < kinoida\n'
# ['<', "kinoida\\n'"]
# < xenia\n'
# ['<', "xenia\\n'"]
# < cityofspheres\n'
# ['<', "cityofspheres\\n'"]
# < oshestak\n'
# ['<', "oshestak\\n'"]
# < igmak\n'
# ['<', "igmak\\n'"]
# < namna\n'
# ['<', "namna\\n'"]
# < puduhepat\n'
# ['<', "puduhepat\\n'"]
# < elarbee\n'
# ['<', "elarbee\\n'"]
# < viks_vaporub\n'
# ['<', "viks_vaporub\\n'"]
# < polinius\n'
# ['<', "polinius\\n'"]
# < camera__oil\n'
# ['<', "camera__oil\\n'"]
# < la_serafina\n'
# ['<', "la_serafina\\n'"]
# < fox_in_burrow\n'
# ['<', "fox_in_burrow\\n'"]
# < nanik_81\n'
# ['<', "nanik_81\\n'"]
# < wasabi79\n'
# ['<', "wasabi79\\n'"]
# < tigra_usa\n'
# ['<', "tigra_usa\\n'"]
# < razor_don\n'
# ['<', "razor_don\\n'"]
# < pripev0chka\n'
# ['<', "pripev0chka\\n'"]
# < sonbahar\n'
# ['<', "sonbahar\\n'"]
# < kolsanova\n'
# ['<', "kolsanova\\n'"]
# < dudetka\n'
# ['<', "dudetka\\n'"]
# < barma_glott\n'
# ['<', "barma_glott\\n'"]
# < pingvin_sr\n'
# ['<', "pingvin_sr\\n'"]
# < das_foland\n'
# ['<', "das_foland\\n'"]
# < ulybchivaya\n'
# ['<', "ulybchivaya\\n'"]
# < je_ni\n'
# ['<', "je_ni\\n'"]
# < lgoldshm\n'
# ['<', "lgoldshm\\n'"]
# < polosatka\n'
# ['<', "polosatka\\n'"]
# < pinyusha\n'
# ['<', "pinyusha\\n'"]
# < kast_spb\n'
# ['<', "kast_spb\\n'"]
# < angelight_a\n'
# ['<', "angelight_a\\n'"]
# < diefrau\n'
# ['<', "diefrau\\n'"]
# < amid1\n'
# ['<', "amid1\\n'"]
# < marina_paz\n'
# ['<', "marina_paz\\n'"]
# < mivak\n'
# ['<', "mivak\\n'"]
# < milaslj\n'
# ['<', "milaslj\\n'"]
# < ministrkultury\n'
# ['<', "ministrkultury\\n'"]
# < alikhin\n'
# ['<', "alikhin\\n'"]
# < postolenka\n'
# ['<', "postolenka\\n'"]
# < a_dyukov\n'
# ['<', "a_dyukov\\n'"]
# < oreganum\n'
# ['<', "oreganum\\n'"]
# < horn_blende\n'
# ['<', "horn_blende\\n'"]
# < taikaaa\n'
# ['<', "taikaaa\\n'"]
# < frenchrus\n'
# ['<', "frenchrus\\n'"]
# < ment52\n'
# ['<', "ment52\\n'"]
# < m_golightly\n'
# ['<', "m_golightly\\n'"]
# < rozetka_q\n'
# ['<', "rozetka_q\\n'"]
# < pulherija\n'
# ['<', "pulherija\\n'"]
# < kozel_na_sakse\n'
# ['<', "kozel_na_sakse\\n'"]
# < derzzkaja\n'
# ['<', "derzzkaja\\n'"]
# < zhabaevent\n'
# ['<', "zhabaevent\\n'"]
# < miaky_miaky\n'
# ['<', "miaky_miaky\\n'"]
# < vareni_k\n'
# ['<', "vareni_k\\n'"]
# < lerche_z\n'
# ['<', "lerche_z\\n'"]
# < yoreshet\n'
# ['<', "yoreshet\\n'"]
# < ms_lizzy_bennet\n'
# ['<', "ms_lizzy_bennet\\n'"]
# < all_is_inside\n'
# ['<', "all_is_inside\\n'"]
# < nucamb_no_necky\n'
# ['<', "nucamb_no_necky\\n'"]
# < bumfufu\n'
# ['<', "bumfufu\\n'"]
# < natatwin\n'
# ['<', "natatwin\\n'"]
# < tegaychik\n'
# ['<', "tegaychik\\n'"]
# < mykidsmom1\n'
# ['<', "mykidsmom1\\n'"]
# < f3\n'
# ['<', "f3\\n'"]
# < myppa\n'
# ['<', "myppa\\n'"]
# < vlada4ka\n'
# ['<', "vlada4ka\\n'"]
# < socbatterfly\n'
# ['<', "socbatterfly\\n'"]
# < olialukoe\n'
# ['<', "olialukoe\\n'"]
# < dame_maggie\n'
# ['<', "dame_maggie\\n'"]
# < kirbka\n'
# ['<', "kirbka\\n'"]
# < maleficente\n'
# ['<', "maleficente\\n'"]
# < glam_blog\n'
# ['<', "glam_blog\\n'"]
# < almira2005\n'
# ['<', "almira2005\\n'"]
# < zemlyanichnoe\n'
# ['<', "zemlyanichnoe\\n'"]
# < st_shtuchka\n'
# ['<', "st_shtuchka\\n'"]
# < zuka1\n'
# ['<', "zuka1\\n'"]
# < delayu_ru\n'
# ['<', "delayu_ru\\n'"]
# < foxy_helen\n'
# ['<', "foxy_helen\\n'"]
# < ratitas\n'
# ['<', "ratitas\\n'"]
# < partizanman\n'
# ['<', "partizanman\\n'"]
# < sanechka_blume\n'
# ['<', "sanechka_blume\\n'"]
# < financepro\n'
# ['<', "financepro\\n'"]
# < elhombresombro\n'
# ['<', "elhombresombro\\n'"]
# < igaljaka\n'
# ['<', "igaljaka\\n'"]
# < bobcatik\n'
# ['<', "bobcatik\\n'"]
# < morseanen\n'
# ['<', "morseanen\\n'"]
# < solovieff_ru\n'
# ['<', "solovieff_ru\\n'"]
# < moscowpoker\n'
# ['<', "moscowpoker\\n'"]
# < aallaa_korg\n'
# ['<', "aallaa_korg\\n'"]
# < insuretravel\n'
# ['<', "insuretravel\\n'"]
# < ne_nogapku\n'
# ['<', "ne_nogapku\\n'"]
# < johnjthunderer\n'
# ['<', "johnjthunderer\\n'"]
# < just_one_girlie\n'
# ['<', "just_one_girlie\\n'"]
# < nushkoshonado\n'
# ['<', "nushkoshonado\\n'"]
# < me_in_usa\n'
# ['<', "me_in_usa\\n'"]
# < grazdano4ka\n'
# ['<', "grazdano4ka\\n'"]
# < kristina_stark\n'
# ['<', "kristina_stark\\n'"]
# < marusia05\n'
# ['<', "marusia05\\n'"]
# < beautyartist\n'
# ['<', "beautyartist\\n'"]
# < jnavigator\n'
# ['<', "jnavigator\\n'"]
# < milavalyacat\n'
# ['<', "milavalyacat\\n'"]
# < fedor778\n'
# ['<', "fedor778\\n'"]
# < yutvar37\n'
# ['<', "yutvar37\\n'"]
# < zigotto\n'
# ['<', "zigotto\\n'"]
# < salme\n'
# ['<', "salme\\n'"]
# < krab2010\n'
# ['<', "krab2010\\n'"]
# < yourlife\n'
# ['<', "yourlife\\n'"]
# < kapturka\n'
# ['<', "kapturka\\n'"]
# < lolagetty\n'
# ['<', "lolagetty\\n'"]
# < moya_kazna\n'
# ['<', "moya_kazna\\n'"]
# < add_new\n'
# ['<', "add_new\\n'"]
# < bodybit\n'
# ['<', "bodybit\\n'"]
# < ib_galochkina\n'
# ['<', "ib_galochkina\\n'"]
# < holy_quant\n'
# ['<', "holy_quant\\n'"]
# < milaanufrieva\n'
# ['<', "milaanufrieva\\n'"]
# < umo\n'
# ['<', "umo\\n'"]
# < jeruhmj\n'
# ['<', "jeruhmj\\n'"]
# < martinea\n'
# ['<', "martinea\\n'"]
# < slurry7\n'
# ['<', "slurry7\\n'"]
# < artem_klyushin\n'
# ['<', "artem_klyushin\\n'"]
# < nayata\n'
# ['<', "nayata\\n'"]
# < stas_liberal\n'
# ['<', "stas_liberal\\n'"]
# < octaviovx\n'
# ['<', "octaviovx\\n'"]
# < dk_zinger\n'
# ['<', "dk_zinger\\n'"]
# < bonne_aventure\n'
# ['<', "bonne_aventure\\n'"]
# < lapoch\n'
# ['<', "lapoch\\n'"]
# < mnogo_piwu\n'
# ['<', "mnogo_piwu\\n'"]
# < dominatorrr\n'
# ['<', "dominatorrr\\n'"]
# < evroru\n'
# ['<', "evroru\\n'"]
# < eta_ja_asya\n'
# ['<', "eta_ja_asya\\n'"]
# < ackeldama\n'
# ['<', "ackeldama\\n'"]
# < serg_was\n'
# ['<', "serg_was\\n'"]
# < gertinskdmitr\n'
# ['<', "gertinskdmitr\\n'"]
# < ponomarevitalik\n'
# ['<', "ponomarevitalik\\n'"]
# < xecco_photo\n'
# ['<', "xecco_photo\\n'"]
# < elsa_fru\n'
# ['<', "elsa_fru\\n'"]
# < mrani67\n'
# ['<', "mrani67\\n'"]
# < olya_babalya\n'
# ['<', "olya_babalya\\n'"]
# < korolkri\n'
# ['<', "korolkri\\n'"]
# < germes06\n'
# ['<', "germes06\\n'"]
# < yauedu\n'
# ['<', "yauedu\\n'"]
# < balkonova\n'
# ['<', "balkonova\\n'"]
# < arinusik333\n'
# ['<', "arinusik333\\n'"]
# < parfumess\n'
# ['<', "parfumess\\n'"]
# < vetrovosssk\n'
# ['<', "vetrovosssk\\n'"]
# < no_globalism\n'
# ['<', "no_globalism\\n'"]
# < diamont_com\n'
# ['<', "diamont_com\\n'"]
# < musjka_03\n'
# ['<', "musjka_03\\n'"]
# < timgud\n'
# ['<', "timgud\\n'"]
# < trirub\n'
# ['<', "trirub\\n'"]
# < krasivey\n'
# ['<', "krasivey\\n'"]
# < qualityperson\n'
# ['<', "qualityperson\\n'"]
# < helpspring2\n'
# ['<', "helpspring2\\n'"]
# < demiurg8888\n'
# ['<', "demiurg8888\\n'"]
# < yyup79\n'
# ['<', "yyup79\\n'"]
# < sass_hummel\n'
# ['<', "sass_hummel\\n'"]
# < alekseyryabtsev\n'
# ['<', "alekseyryabtsev\\n'"]
# < natura_andrey\n'
# ['<', "natura_andrey\\n'"]
# < thenyashdiaries\n'
# ['<', "thenyashdiaries\\n'"]
# < lefortoff\n'
# ['<', "lefortoff\\n'"]
# < gogol\n'
# ['<', "gogol\\n'"]
# < camoe\n'
# ['<', "camoe\\n'"]
# < sergey_gora\n'
# ['<', "sergey_gora\\n'"]
# < hamptonlanny\n'
# ['<', "hamptonlanny\\n'"]
# < lara_x\n'
# ['<', "lara_x\\n'"]
# < nikolay_suslov\n'
# ['<', "nikolay_suslov\\n'"]
# < donna_marta\n'
# ['<', "donna_marta\\n'"]
# < beauty_co\n'
# ['<', "beauty_co\\n'"]
# < alexmonc\n'
# ['<', "alexmonc\\n'"]
# < leo_taxil\n'
# ['<', "leo_taxil\\n'"]
# < altruisttka\n'
# ['<', "altruisttka\\n'"]
# < untitande\n'
# ['<', "untitande\\n'"]
# < marynog\n'
# ['<', "marynog\\n'"]
# < valmsn\n'
# ['<', "valmsn\\n'"]
# < goodspider\n'
# ['<', "goodspider\\n'"]
# < sosedgeorg\n'
# ['<', "sosedgeorg\\n'"]
# < pavel_ist\n'
# ['<', "pavel_ist\\n'"]
# < glebminskiy\n'
# ['<', "glebminskiy\\n'"]
# < maximkamax\n'
# ['<', "maximkamax\\n'"]
# < s_to4ki_zrenia\n'
# ['<', "s_to4ki_zrenia\\n'"]
# \n'
# ["\\n'"]

# %%
def snowball_sampling(g, center, max_depth=1, current_depth=0, taboo_list=[]):
    # if we have reached the depth limit of the search, bomb out.
    print(center, current_depth, max_depth, taboo_list)
    if current_depth==max_depth: 
        print('out of depth')
        return taboo_list
    if center in taboo_list:
        print('taboo')
        return taboo_list #we've been here before
    else:
        taboo_list.append(center) # we shall never return
        
    read_lj_friends(g, center)
    
    for node in g.neighbors(center):
        taboo_list=snowball_sampling(g, node, current_depth=current_depth+1, max_depth=max_depth, taboo_list=taboo_list)
    
    return taboo_list

# %%
g=net.Graph()
snowball_sampling(g,'kozel_na_sakse')
# Out:
# kozel_na_sakse 0 1 []
# cr 1 1 ['kozel_na_sakse']
# out of depth
# saper 1 1 ['kozel_na_sakse']
# out of depth
# ptfenix 1 1 ['kozel_na_sakse']
# out of depth
# guy_gomel 1 1 ['kozel_na_sakse']
# out of depth
# klari 1 1 ['kozel_na_sakse']
# out of depth
# dachte 1 1 ['kozel_na_sakse']
# out of depth
# solo_oboroten 1 1 ['kozel_na_sakse']
# out of depth
# zina_korzina 1 1 ['kozel_na_sakse']
# out of depth
# kirulya 1 1 ['kozel_na_sakse']
# out of depth
# letchikleha 1 1 ['kozel_na_sakse']
# out of depth
# usolt 1 1 ['kozel_na_sakse']
# out of depth
# jolita 1 1 ['kozel_na_sakse']
# out of depth
# periskop 1 1 ['kozel_na_sakse']
# out of depth
# valerois 1 1 ['kozel_na_sakse']
# out of depth
# cher_no_more 1 1 ['kozel_na_sakse']
# out of depth
# to_to_i_ono_to 1 1 ['kozel_na_sakse']
# out of depth
# cheese_people 1 1 ['kozel_na_sakse']
# out of depth
# olga_mama 1 1 ['kozel_na_sakse']
# out of depth
# ak_bara 1 1 ['kozel_na_sakse']
# out of depth
# gde_moi_mozgi 1 1 ['kozel_na_sakse']
# out of depth
# tanyakotova 1 1 ['kozel_na_sakse']
# out of depth
# sovarh 1 1 ['kozel_na_sakse']
# out of depth
# oshestak 1 1 ['kozel_na_sakse']
# out of depth
# nikitosbro 1 1 ['kozel_na_sakse']
# out of depth
# dr_livsig 1 1 ['kozel_na_sakse']
# out of depth
# emjudob 1 1 ['kozel_na_sakse']
# out of depth
# dumjtio 1 1 ['kozel_na_sakse']
# out of depth
# vujurja 1 1 ['kozel_na_sakse']
# out of depth
# orteme_ru 1 1 ['kozel_na_sakse']
# out of depth
# husky_wardsa 1 1 ['kozel_na_sakse']
# out of depth
# jenya_salaveya 1 1 ['kozel_na_sakse']
# out of depth
# fartasssea 1 1 ['kozel_na_sakse']
# out of depth
# olimkasaz 1 1 ['kozel_na_sakse']
# out of depth
# pussbigeyesz 1 1 ['kozel_na_sakse']
# out of depth
# plastickfreakz 1 1 ['kozel_na_sakse']
# out of depth
# gingea 1 1 ['kozel_na_sakse']
# out of depth
# hamptonlanny 1 1 ['kozel_na_sakse']
# out of depth
# ['kozel_na_sakse']

# %%
net.write_pajek(g,'lj_friends.net')

# %%
g=net.read_pajek('russians.net')
len(g)
deg=net.degree(g)
# Out:
# 232

# %%
deg
# Out:
# {'maly_na': 1,
#  'koradokosta': 1,
#  'reinkarni': 2,
#  'cartoonka': 1,
#  'prihodi_smotri': 1,
#  'pgrigas': 2,
#  'riendespe': 1,
#  'musechka': 1,
#  'chijulia': 1,
#  'blga': 1,
#  'gogokostik': 1,
#  'hieroglyph_elle': 1,
#  'demettry': 1,
#  'nata_f_e_ya': 4,
#  'saburay': 1,
#  'idealsummer': 1,
#  'esta_midea': 1,
#  'sarodgini': 3,
#  'cedov_cergey': 1,
#  'kharkov_toronto': 1,
#  'money4you': 6,
#  'sushka_gim': 1,
#  'slayerovich': 2,
#  'azzy_kikoz': 1,
#  'guiness_2010': 2,
#  'indeezzz': 1,
#  'a_philatov': 1,
#  'anfatransf': 1,
#  'podarokua': 1,
#  'stepnoy_lis': 1,
#  'murik_555': 1,
#  'osunsion': 1,
#  'sakura_nu': 2,
#  'broshko': 2,
#  'ihavesage': 1,
#  'von_tageslicht': 1,
#  'gypsymelody': 1,
#  'iron_marg': 1,
#  'dionte_zicarel': 1,
#  'lovesexandmoney': 1,
#  'izmest': 1,
#  'asmi_u': 1,
#  'ivar59': 2,
#  'poupee_russe': 1,
#  'lilya_p': 1,
#  'liana_23b': 1,
#  'kipriena': 1,
#  'azuresky2006': 2,
#  '_ghost_pulse_': 1,
#  'mary_tudor': 1,
#  'vivisin': 5,
#  'zakazfromusa': 1,
#  'atom_golany': 2,
#  'valja_vorobjoff': 1,
#  'notolya': 1,
#  'nashlykid': 1,
#  'monsenor': 1,
#  'xerasse': 1,
#  'no_lullaby': 1,
#  'petr26': 2,
#  'viesel': 1,
#  'elenushka': 1,
#  'busrra': 1,
#  'novoromantik': 1,
#  'zaleph': 5,
#  'zosuspend_mnu': 1,
#  'ajgul': 2,
#  'schenkh': 1,
#  'a_nagayna': 1,
#  'vladimirgin': 4,
#  'luda_berlin': 3,
#  'p_n_z_8_8': 1,
#  'darth_bender': 1,
#  'popov_sergey_ru': 1,
#  'pantufly': 1,
#  'me_galka': 1,
#  'neo_neon': 1,
#  'andreism': 1,
#  'xalal4ullag': 3,
#  'maneulv': 1,
#  '_vopros': 1,
#  'nadeyka_sh': 2,
#  'mphedoseeva': 2,
#  'wilmore23': 1,
#  'zapis_segodny': 2,
#  'remochka': 2,
#  'grazgdanin': 1,
#  'ffoo': 1,
#  '274': 1,
#  'elvingamarie': 1,
#  'beardedguru': 3,
#  'pani_ga': 1,
#  'eva_nadu': 1,
#  'sointransigente': 1,
#  'designer_plya': 1,
#  'slivka20': 1,
#  'humanitarium': 1,
#  'shakariazia': 2,
#  'suvorow_': 1,
#  'ungelt': 2,
#  'colt_browning': 1,
#  'elve': 1,
#  'pawet': 1,
#  'wild_wild_ash': 1,
#  'clementine_mil': 2,
#  'qbeth': 1,
#  'vladon': 1,
#  'urd_norman': 1,
#  'olmeka': 7,
#  'ehecate': 3,
#  'verticaltreck': 4,
#  'amaliaehnsh': 3,
#  'zanoza_j': 1,
#  'bumbiere': 3,
#  'amnuel': 3,
#  'tat_carera': 1,
#  'jrc4558': 3,
#  'ezhan': 1,
#  'besttoday': 2,
#  'evangellin': 1,
#  'suntin': 1,
#  'noizzzefixxxion': 1,
#  'lakschmi': 1,
#  'bashstalk': 1,
#  'musin_rustam': 1,
#  'yulce': 1,
#  'seiv': 1,
#  'negodniki': 1,
#  'nunya_n': 1,
#  'zeffiroso': 1,
#  'leanezoo': 1,
#  'kohanna': 2,
#  'kelonjk': 1,
#  'sunbeam_': 1,
#  'valorieqs': 1,
#  'dorygrey': 2,
#  'gabbear': 1,
#  'malsinc': 2,
#  'samadama': 1,
#  'solvita': 1,
#  'tulo_spinwolf': 1,
#  'allenzet': 1,
#  'vovalcano': 1,
#  'werton': 1,
#  'romacha': 1,
#  'slonikoff_net': 1,
#  'chtez': 1,
#  'frau_mia': 2,
#  'lyamba': 1,
#  'ftvn_2010': 1,
#  'nata_shi': 2,
#  'ap_ata': 2,
#  'dulcinea_nata': 1,
#  'shaulreznik': 9,
#  'pisankov': 1,
#  'defrostik': 1,
#  'alexizm': 2,
#  'mass_media_ua': 1,
#  'elentin': 2,
#  'adesty': 1,
#  'catch_': 1,
#  'shtabss': 3,
#  'a_n_c_o_r': 1,
#  'miranduht': 1,
#  'sterk': 1,
#  'yanoos': 1,
#  'battisto': 1,
#  'launch4you': 1,
#  'freken_sniff': 1,
#  'fleur_de_cassie': 1,
#  'eltheriol_jew': 4,
#  'montagnard': 1,
#  'tofu_russia': 1,
#  'esliseksa_net': 1,
#  'dilanbim': 2,
#  'vesna_1965': 1,
#  'gulnaz': 2,
#  'ur_sun': 2,
#  'unab0mber': 1,
#  'lolyes': 1,
#  'alipchik': 2,
#  'valeks': 2,
#  'irkku777': 1,
#  'cannibal': 3,
#  'rimma_bbusia': 1,
#  'trequarta': 1,
#  'dr_divisenko': 1,
#  'hnyamohnya': 1,
#  'savenkov': 2,
#  'kitten_z': 1,
#  'auth_r': 8,
#  'high_on_toes': 1,
#  'norapotapova': 1,
#  'goshmarik': 1,
#  'serapion82': 1,
#  'koro4ka': 2,
#  'taksus': 1,
#  'rustamchik': 1,
#  'loktev': 1,
#  'contessa7': 2,
#  'lusiaparty': 1,
#  'kuk_ua': 1,
#  'orechiv': 1,
#  'coffeetale': 2,
#  'snorkelstein': 3,
#  'abeliakov': 1,
#  'valitova': 1,
#  'bent_insomnia_m': 1,
#  'kolenki': 1,
#  '_nikolay': 2,
#  'ladyanechka': 1,
#  'keen_on_you': 1,
#  'nu_ance': 1,
#  'redkvoevoe': 1,
#  'chr0matin': 1,
#  'punk72': 1,
#  'aquafea': 2,
#  'jia_dragon': 1,
#  '_odinn_': 1,
#  'turbeeyon': 4,
#  'borzova_daria': 1,
#  'crazy_wind': 2,
#  'wutka': 3,
#  'tsaritsa_makosh': 1,
#  'cazadora_2': 1,
#  'yolka13': 2,
#  'svetlana_tx': 1,
#  'theredone': 1,
#  'lizard__queen': 4,
#  'gerdaxxi': 1,
#  'alcedorussicus': 1,
#  'artmotion': 2,
#  'kaizer_tg': 1,
#  'mulya_diana': 2,
#  'kletki': 1,
#  'mari_anna': 2,
#  'k_stein': 2,
#  'gourry_aka_pm': 1,
#  'point_666': 3,
#  'dazdraperma_k': 2,
#  'andrelet': 1,
#  'grassface': 1,
#  'eva360': 3,
#  'lucky_delf': 2,
#  'marizelsu': 1,
#  'ajojo': 1,
#  'kengako': 1,
#  'i_chin': 1,
#  'yukinochka': 1,
#  'dmitin': 1,
#  'forrary': 2,
#  '_diesel_': 1,
#  'boddah_caster': 1,
#  'im_spring': 1,
#  'mariamz': 4,
#  'x_style': 1,
#  'trimfaktor': 1,
#  'lib_ry': 1,
#  'olya_lya_': 2,
#  'blog_nexta': 1,
#  'jntra': 1,
#  'lunika': 1,
#  'ikar_2': 2,
#  'tasilda': 3,
#  'daritta': 5,
#  'absolut_': 1,
#  'darina29': 1,
#  'izluchatel': 1,
#  'lyuniso': 2,
#  'studio_maneken': 1,
#  'seioneira': 1,
#  'mira_a': 1,
#  'palsmarties': 1,
#  'deva_m': 1,
#  'fortochka': 8,
#  'nilkin': 1,
#  '__dobriy_t__': 2,
#  'konsumterra': 1,
#  'miss_grace': 4,
#  'delfin_1975': 1,
#  'lite_lite_lite': 1,
#  'red_valjok': 1,
#  'grenzlos': 1,
#  '_ina_ya_': 1,
#  'lthdbi': 1,
#  'tanyastakhanova': 3,
#  'swechka': 6,
#  'gran_aventura': 1,
#  'medve_ed': 1,
#  'twilight_g': 1,
#  'kamenskii': 1,
#  'tom_i_lina': 4,
#  'otverzhennaia': 1,
#  'bsng': 1,
#  'lucky_aka_vera': 1,
#  'dzokonda': 2,
#  'anndii': 1,
#  '_lama': 1,
#  'pg_bardin': 3,
#  'don_sever': 2,
#  'bytmojet': 1,
#  'anatoliypost': 1,
#  'kakaschenko': 2,
#  'neverland333': 1,
#  'trunes': 1,
#  'geenevra': 1,
#  'angelita24': 1,
#  'lolapokakala': 1,
#  'svetlaya_lesya': 1,
#  'lubard_on_line': 1,
#  'zorraestelar': 1,
#  'tendress': 1,
#  'catharsis_way': 1,
#  'rabarbar': 1,
#  'didebuli': 1,
#  'deodan': 1,
#  'yusuper': 1,
#  'ljucia': 3,
#  'iren_rose': 3,
#  'kapelsin': 1,
#  'plucer': 3,
#  'nadyaruss': 1,
#  'lady_ester': 1,
#  'antivit': 2,
#  'puma_blanca': 1,
#  'babira': 1,
#  'supercoupon': 1,
#  'hitlerolog': 1,
#  'reallaer': 1,
#  'chudonapalochke': 1,
#  'expert_online': 2,
#  'oleg_dunaev': 2,
#  'daria_colada': 1,
#  'star_veselchak': 1,
#  'cat_ty': 1,
#  'timofeyeva': 1,
#  'fishunia': 2,
#  'borzh': 1,
#  'garciajeans_ukr': 1,
#  'carpenco': 1,
#  'belleelle': 1,
#  'gingerella': 5,
#  'goooseberry': 3,
#  'tatiana_siver': 1,
#  'underworld14': 1,
#  'trayma': 1,
#  'blckwngedroses': 1,
#  'dowload_here': 1,
#  'nimuravka': 6,
#  'fif': 14,
#  'zvezdo4kaman9': 1,
#  'realya': 1,
#  'marina_z_s': 2,
#  'bambookin': 1,
#  'tsiana': 2,
#  'alyona_l': 1,
#  'elena_mihno': 1,
#  'minimaldeep': 1,
#  'isida': 1,
#  'my_sex_dnevnik': 1,
#  'treatment_child': 1,
#  'tokuiayasu': 1,
#  'kapirk': 1,
#  '13mayapple13': 1,
#  'cars_drive': 5,
#  'miayyy': 1,
#  'schastje_moe': 1,
#  'scindapsus': 1,
#  'resnicy': 1,
#  'bublik64': 6,
#  'le_taxidermiste': 1,
#  'strizhkov': 1,
#  'aleks_ter': 2,
#  'mamkadoctor': 4,
#  'bnnnnd_spb': 1,
#  'sova': 2,
#  'serdcem_i_duwoj': 1,
#  'musyavaya': 1,
#  'maupiti': 2,
#  '__kisa': 1,
#  'nt4friends': 1,
#  'lenavoronova': 1,
#  'dama_s_kamnyami': 1,
#  'free_emotion': 1,
#  'kerberusha': 2,
#  'kurrguzova': 1,
#  'sad2007': 1,
#  'fasol_bobovay': 1,
#  '04manska9': 1,
#  '_bbw': 4,
#  'spawn_garret': 1,
#  '_evo': 1,
#  'ezhi_mil': 1,
#  'femme_exotique': 1,
#  'scepticist': 1,
#  '_superv_': 1,
#  'khairullina': 1,
#  'donnna_rosa': 2,
#  'nadorich': 1,
#  'red_ashberry': 2,
#  'langusta': 1,
#  'more_vnutri': 1,
#  'dina_empire': 1,
#  'un_reve': 4,
#  'matv2hoda': 2,
#  'isya': 1,
#  'dasha_kiev': 1,
#  'cn_mangetsu': 1,
#  'mrkaterin': 1,
#  'nika_smile': 1,
#  'shushencija': 1,
#  'luwyt': 1,
#  'nesya': 2,
#  'holiday_n': 1,
#  'allaq': 3,
#  'pepsiman6': 1,
#  'la_cappadocia': 3,
#  'svvallovv': 1,
#  'in_dee': 1,
#  'nagikcko': 1,
#  'katrin_84': 1,
#  'edodolev': 2,
#  'chekesha': 2,
#  'thecode': 2,
#  'avaku': 1,
#  'avaks': 1,
#  'und333': 2,
#  're_diez': 1,
#  '_snusmumrik': 3,
#  'rinamari': 2,
#  'fess_84': 1,
#  'igor_sizov': 1,
#  '1kino': 2,
#  'mazul': 1,
#  'holly_inna': 1,
#  'tany_06': 1,
#  'vladoga': 1,
#  'd_r_i_v_e': 1,
#  'anna_move': 9,
#  'atasss': 1,
#  'poignant_art': 1,
#  'abramovv': 3,
#  'stasiaa': 2,
#  'lake_spirit': 2,
#  'kozlevski': 2,
#  'my_flickr_faves': 1,
#  'dorenko': 1,
#  'olga_myakota': 1,
#  'vetaliano': 1,
#  'graf_vk': 1,
#  'natalia1974': 1,
#  'fkusno': 1,
#  'vg36': 2,
#  'pustota1': 1,
#  'jinjer_flover': 2,
#  'serg_stepan': 1,
#  'slaneyder': 1,
#  'tashal': 1,
#  'lemur_lori': 5,
#  'kolzina': 1,
#  'i_crust': 14,
#  'penguin_lolo': 1,
#  'anfisiy': 1,
#  'loralains': 7,
#  'tatzay': 1,
#  'nasekomof': 3,
#  'asukachev': 1,
#  'chumak2005': 1,
#  'illeniya': 2,
#  'ya_puchu_glaz': 1,
#  'iaugen': 1,
#  'panda_684': 3,
#  'slaw_alena': 2,
#  'ne_prosto_mama': 1,
#  'kuh_nja': 1,
#  'ljizka': 1,
#  'aushedg': 1,
#  'cosmophoto': 1,
#  'kris_tall': 3,
#  'asatokenji': 1,
#  'natalya_abramov': 1,
#  'semero_smelyh': 1,
#  'myxamyxa': 1,
#  'tanjas': 1,
#  'nati_nata': 1,
#  'ggpp': 1,
#  'tan_go': 2,
#  'olgatallinn': 1,
#  'abzaz': 1,
#  'whiskyblog': 1,
#  'arsbam': 2,
#  'belorusska': 1,
#  'ladyganesha': 2,
#  'danka_pu': 1,
#  'back_in_me': 1,
#  'deligia': 2,
#  'donvictorio': 1,
#  'malashka': 4,
#  'vati_1978': 1,
#  'palcev': 1,
#  'cherny_bada': 2,
#  'deadshadow': 3,
#  'bridgetjones_ny': 8,
#  'alex_nik': 1,
#  'designghost': 1,
#  'sha_nezhka': 1,
#  'sky_rhymer': 1,
#  'avprokofiev': 1,
#  'your_eithery': 3,
#  'jannatt': 3,
#  'superolga': 1,
#  'anlahel': 1,
#  'alenochkav': 1,
#  'kseniapinto': 1,
#  'morskayaaa': 1,
#  'alena_stepanova': 1,
#  'step05': 1,
#  'vi_1981': 1,
#  'dedpihto': 2,
#  'lis_andra': 1,
#  'azatsh': 1,
#  'dimka_plotnikov': 1,
#  'pal_petrovich': 3,
#  'vgerzane': 1,
#  'lolly_diva': 4,
#  'cccameron': 1,
#  'lollochka': 1,
#  'shansproducer': 1,
#  'krem_brulle': 4,
#  'kvito4ek': 2,
#  'anetak': 2,
#  'kisa_murka': 2,
#  'ditafontiz': 1,
#  'msmolyak': 1,
#  'olenka_vlad': 1,
#  'kf4': 1,
#  'trofimov_sn': 1,
#  'ksu_ipekakuana': 1,
#  'aelita_forget': 1,
#  'vesnushkacat': 1,
#  'dieweiseeule': 2,
#  'dark_seaman': 1,
#  'a1eksan9ra': 1,
#  'vladika_fokina': 1,
#  'nikolaeva_anna': 1,
#  '_tori_': 2,
#  'teyli_tei': 1,
#  'sandrixxx': 2,
#  'alexwilf': 1,
#  'ledi_kenleh': 1,
#  'gis_girl': 1,
#  'xmelnikov': 1,
#  'vinzilit': 1,
#  'telemakh': 2,
#  'godosha': 1,
#  'foxly': 2,
#  '011615': 1,
#  'smuke': 1,
#  'polmuaddib': 1,
#  'temik319': 3,
#  'yarosh_ka': 1,
#  'expatka': 1,
#  'musictube_ru': 4,
#  'ksandr10': 2,
#  'terricola': 2,
#  'lunnaya_belka': 2,
#  'shperk': 2,
#  'stoit_v_teni': 1,
#  'tyrichavp': 1,
#  'copperlady': 1,
#  'achtung_com_ua': 1,
#  'fuckeach': 1,
#  'toxa_slag': 1,
#  'novizhdy': 1,
#  'sonceniatko': 2,
#  'svobodnaptichka': 1,
#  'ingunn_helge': 1,
#  'open_air_nu': 2,
#  'allegoria': 1,
#  'talerka_ru': 1,
#  'pjoter_ivanov': 1,
#  'apalikulinda': 1,
#  'musikk': 2,
#  'freedom_consult': 1,
#  'winston_two': 1,
#  'ninapti': 2,
#  'ixci': 1,
#  'emo_chaos': 1,
#  'goddamn_russkie': 1,
#  'nutly': 5,
#  'frida_friends': 1,
#  'l_mariam': 3,
#  'hsot': 1,
#  'supremsokol': 1,
#  'boevoi_zayats': 1,
#  'vika_dika': 1,
#  'diabelek': 8,
#  'teatr_vkusa': 1,
#  'vgo': 1,
#  'boberrulit': 1,
#  'in_opposition': 1,
#  'chimaerandi': 1,
#  'f1ct1_on': 1,
#  'bj_ba': 1,
#  'moe_imya_lisa': 1,
#  'bonafiden': 8,
#  'krasota007': 1,
#  'talentjr': 1,
#  'mumms': 1,
#  'fra_dominic': 1,
#  'mitek_mitekych': 1,
#  'zhevtun': 1,
#  'margo_na': 1,
#  'oprion': 1,
#  '1satana': 3,
#  'echidnaa_lavisi': 3,
#  'besheniy67': 1,
#  'hot_dognitsa': 1,
#  'volkar': 1,
#  'ohnegrenzen': 1,
#  'valeria_st': 4,
#  'denius': 1,
#  'seo4nik': 1,
#  'mr_quietest': 8,
#  'tokio_paris': 1,
#  'ne_napokaz': 1,
#  'oxania': 1,
#  'i_beauty': 1,
#  'arkady1': 1,
#  'kinoistoriya': 1,
#  'krechetova': 2,
#  'lc_players': 1,
#  'deniszheleznyy': 1,
#  'robinzon_girl': 1,
#  'amfibol': 1,
#  'b00t': 1,
#  'yabloki_tybloki': 1,
#  'bzdyshek': 1,
#  'rebekkka': 2,
#  'mkoenig': 2,
#  'exjt': 1,
#  'quaeritans': 1,
#  'asiyath': 1,
#  'radegost': 2,
#  'garret_lab': 1,
#  'barolya': 1,
#  'gazirovannaja': 3,
#  '0ffline': 1,
#  'mellot': 1,
#  'saul_paradise': 4,
#  'charunga': 1,
#  'iron_ksu': 2,
#  'droanton': 1,
#  'krestiknolik': 1,
#  'credo_always': 1,
#  'stefanel_lora': 1,
#  'nahalenok': 1,
#  'shurikdc': 1,
#  'alfalfalfa': 1,
#  'fobious': 1,
#  'senmurv': 1,
#  'lenochka11': 1,
#  'matilda_ussr': 1,
#  'ann_orlova': 1,
#  'vechnaia_zima': 1,
#  'otello': 1,
#  'ersil': 2,
#  'mobis33': 1,
#  'kumiko_artistka': 1,
#  'domkratov': 1,
#  'temptee': 4,
#  'aintlion': 2,
#  'deatravel': 1,
#  'i_n_n': 2,
#  'simcha_eichel': 1,
#  'likeladygodiva': 1,
#  'skras': 1,
#  'korolka': 2,
#  'irena_iris': 4,
#  'orleanz': 4,
#  'maminbluz': 1,
#  'indig0z': 3,
#  'aksuk': 1,
#  'sunleoka': 1,
#  'tigra_katy': 2,
#  'rock_f': 1,
#  'dushegubik': 1,
#  'shpion14': 1,
#  'radostev_v': 1,
#  'moerta': 2,
#  'veryloving': 1,
#  'bulfriend': 3,
#  'screechowl_uhu': 2,
#  'jewelin': 1,
#  'upiachka': 1,
#  '_tankist': 1,
#  'marineval': 1,
#  'okhalatnikova': 1,
#  'ajushka': 1,
#  'stobla': 1,
#  'xujasse': 1,
#  'shtykh': 1,
#  'aprel': 1,
#  'dr_vodka': 1,
#  'stichelmeister': 2,
#  'young_pickup': 1,
#  'anirinka': 7,
#  'polit_mudak': 1,
#  '6atenka': 1,
#  'technograf': 1,
#  'kosterina': 2,
#  'puchs': 1,
#  'awyr': 1,
#  'lentochka_ts': 1,
#  'towerkeeper': 1,
#  'monusya': 1,
#  'twaneq': 1,
#  'blueray': 1,
#  'f_lia': 1,
#  'peggy_s': 4,
#  'bulinat': 1,
#  'fucktohell': 2,
#  'arctickfox1911': 1,
#  'carmmen': 1,
#  'avotiya': 3,
#  'flying_bee2': 1,
#  'maxteror': 1,
#  'mclaren2000': 1,
#  'ys_pumpui': 1,
#  'pampulus': 4,
#  'kizhajla': 1,
#  'rudenko_s': 1,
#  'straytrain': 1,
#  'thebestya': 3,
#  'konoza': 1,
#  'yama_nov': 1,
#  'spleza': 1,
#  'madamchic': 1,
#  'anegra': 2,
#  'de_kor': 1,
#  'lugerr': 1,
#  'igor_mkrt': 12,
#  'cheshire_pig': 7,
#  'kucha_mala': 7,
#  'minimum_riska': 1,
#  'nishtyak': 1,
#  'nadiki': 1,
#  'its_funky': 1,
#  'apo_monitor': 1,
#  'moon_abbys': 1,
#  '_gromova_': 1,
#  'trivee': 1,
#  'webdevel': 1,
#  'immoralist': 26,
#  'n0vikova': 3,
#  'charliesies': 3,
#  'spy_read': 1,
#  'zelda_cat': 1,
#  'tolstiy': 2,
#  'bella_choo': 1,
#  'sprvyta': 1,
#  'lavictoria': 1,
#  'ponka_kiev': 1,
#  'rabauken': 2,
#  'almog': 1,
#  'starayakniga': 3,
#  'yoko_squaw': 1,
#  'atomy': 1,
#  'vidimopanda': 1,
#  'iry': 2,
#  'sasha_voropaev': 1,
#  'mikeorl': 4,
#  'oldbore': 1,
#  'lenusch11': 2,
#  'freeraser': 1,
#  'irr': 2,
#  'bezlepkina': 6,
#  'posovetui': 2,
#  'segodnya': 4,
#  'laoshe': 2,
#  'akm_akm': 1,
#  'hina_chleck': 1,
#  'x_polkovnik': 1,
#  'jinjerd': 3,
#  'violin_fox': 1,
#  'ivan_rosa': 1,
#  'yzhka': 1,
#  'shelter_a': 1,
#  'koza_nostra': 1,
#  'bodraschy_lesch': 1,
#  'zubnik_fabrique': 1,
#  'estlona': 1,
#  'rttv': 1,
#  'zajchevskij': 1,
#  's0n1c': 1,
#  'klotti': 2,
#  'blanqi': 2,
#  'squo': 1,
#  'sun_day': 1,
#  'munakokkelli': 1,
#  'mlledefer': 1,
#  'nikesha': 1,
#  'ggmarketing': 1,
#  'ada_samarka': 2,
#  'mina_und_otto': 1,
#  'loftetagi': 1,
#  'nob239': 1,
#  'citywoman': 2,
#  'lucysd': 1,
#  'm_ul_s': 1,
#  'winniepooh_i_k': 3,
#  'soljarka': 1,
#  'pro4off': 1,
#  'sky_thunder': 1,
#  'viaceslavut': 1,
#  'natasha_kob': 1,
#  'japshum': 1,
#  'lark_dis': 2,
#  'a_bl': 1,
#  'moravit': 1,
#  'denisuy': 1,
#  'voi_voi': 1,
#  'u_l_i_n_k_a': 2,
#  'iris_k': 1,
#  'life_and_islam': 3,
#  'ce_man': 1,
#  'chelovek': 1,
#  'kino_bez_graniz': 1,
#  'esperance1': 1,
#  'erstebankua': 1,
#  'finnmo': 2,
#  'garfield_y': 5,
#  'bothman': 1,
#  'karrykarry': 1,
#  'bod_hi': 1,
#  'dzyubochka': 2,
#  'yahoo_zloi': 1,
#  'nettless': 3,
#  'organs_pusher': 2,
#  'garfield_s': 3,
#  'x_line': 1,
#  'leynell': 1,
#  'furzicle': 1,
#  'izummmm': 2,
#  'vlodamir': 1,
#  'new_azzia': 1,
#  'virgofelix': 1,
#  'si_matro': 1,
#  'lledanni': 3,
#  'mmontecarlo': 1,
#  'basque': 3,
#  'deferre': 6,
#  'grimmy3d': 1,
#  'ice_nugget': 1,
#  'yuliaskrap': 1,
#  'kekoza': 1,
#  'odri_hepbern': 1,
#  'onikuz': 1,
#  'dimqa': 1,
#  'totsvet': 2,
#  'strongholder': 1,
#  'voblic': 3,
#  'ieiesj': 1,
#  'fashuggah': 1,
#  'a_galaxy': 2,
#  'elenavi': 1,
#  'vova_chuma': 1,
#  'lana_kou': 3,
#  'frr': 2,
#  'visnushko': 1,
#  'noger_vruker': 1,
#  'detenish': 4,
#  'tutux': 1,
#  'art_gudkof': 1,
#  '_yana': 1,
#  'naife': 1,
#  '__cara__': 1,
#  'vi_laschenov': 1,
#  'fruto': 1,
#  'kvakshi': 4,
#  'regul': 2,
#  'wwwnastenawww': 1,
#  'mahaon_ysh': 1,
#  'ryzhaya_zluchka': 2,
#  'ivkoshkin': 1,
#  'perlovka_blog': 2,
#  '_jilly_': 1,
#  'janataha': 2,
#  'kondratti': 2,
#  'masam_3': 1,
#  'kala_hansa': 1,
#  'busyana': 1,
#  'kapitoshik': 2,
#  'jeol': 7,
#  'tazmaniand_evil': 1,
#  'novi_9': 2,
#  'rina_grant': 1,
#  'lomenille': 1,
#  'sergei_anufriev': 1,
#  'string_fever': 1,
#  'akusti4ka87': 1,
#  'zvetok_sakuri': 1,
#  'brilly23': 1,
#  'molcaxitl': 1,
#  'kikimora_b': 6,
#  'azbonfad': 1,
#  'zakata': 3,
#  'oustinov': 1,
#  'inessa_b': 4,
#  'intaf': 3,
#  'br_andr': 1,
#  'assolata': 2,
#  'igorsadkof': 1,
#  'belov_artstudio': 1,
#  'kidw': 1,
#  'm_paramonov': 1,
#  'poddubnyy59': 1,
#  'vitbel2000': 1,
#  'reydan': 1648,
#  'damirs': 1,
#  'hydrargirum': 1,
#  'ioscat': 1,
#  'groats': 6,
#  'inessa_v': 3,
#  'a_vysotskiy': 1,
#  '_agorafobia_': 1,
#  'rmorga': 1,
#  'nasuto_procione': 1,
#  'shupaka': 2,
#  'bombey': 2,
#  'zalmax': 2,
#  'free_elefant': 2,
#  'willy_sever': 1,
#  'mfermin': 1,
#  'shiros': 11,
#  'arhangelsky': 1,
#  'gobuz': 2,
#  'haxah': 1,
#  'ta_shenka': 1,
#  'swiss_wife': 2,
#  'slayter': 1,
#  'mishka_kaola': 2,
#  'vitavini': 2,
#  'kipzt': 1,
#  'all_abaut': 2,
#  'n_e': 1,
#  'igornem': 1,
#  'anaeill_nitting': 1,
#  'foshizd': 1,
#  'kot1972': 1,
#  'oygenn': 1,
#  'alien_u2': 1,
#  'biancoloto': 1,
#  'lollip0pa': 3,
#  'aentelis': 3,
#  'principall': 1,
#  'milewska': 1,
#  'ice_skws': 1,
#  'tejido': 1,
#  'discreet_chaos': 1,
#  'aaafnbn': 1,
#  'djtonik': 1,
#  'zench': 2,
#  'yellowsmoke1': 2,
#  'scaramel': 1,
#  'evjenia': 1,
#  'valenok8': 1,
#  'pepe_47': 1,
#  'n_a_d_i': 1,
#  'krootee': 1,
#  'nakkiga': 1,
#  'devochk0': 1,
#  'true_sergio': 1,
#  'fiquet': 1,
#  'chek_100': 3,
#  'zhukola': 1,
#  'guruken': 1,
#  'ph_b': 4,
#  'baby_malishka': 1,
#  'mm_jam': 2,
#  '81les': 1,
#  '0l0': 3,
#  'socialism_vk': 2,
#  'vladfe': 4,
#  'keiretbe': 1,
#  'kolchakark': 1,
#  'kussike': 1,
#  'boziya_korovka': 1,
#  'bazjak': 1,
#  'georgich': 1,
#  'shnaps': 1,
#  'v_olga_dnepr': 2,
#  'indrik_book': 1,
#  'gorbarsky': 1,
#  '2keys': 1,
#  'morgulis': 4,
#  'lepeztok': 2,
#  'irishka51254': 1,
#  'liilaa': 2,
#  'solga77': 2,
#  ...}

# %%
min(deg.values())
# Out:
# 1

# %%
max(deg.values())
# Out:
# 4691

# %%
def sorted_map(map1):
    ms = sorted(map1.items(), key=lambda k: -k[1])
    return ms

# %%
ds=sorted_map(deg)
ds[0:9]
# Out:
# [('borisakunin', 4691),
#  ('doctor_liza', 3046),
#  ('tareeva', 2970),
#  ('cheger', 2887),
#  ('karial', 2717),
#  ('snorapp', 2707),
#  ('masha_koroleva', 2683),
#  ('elladkin', 2616),
#  ('samoleg', 2597)]

# %%
import matplotlib.pyplot as plt

# %%
h=plt.hist(list(deg.values()),100)
plt.show()

# %%
plt.loglog(h[1][1:],h[0])
plt.show()

# %%
def trim_degrees(g, degree=1):
    g2=g.copy()
    d=net.degree(g2)
    for n in g2.nodes():
        if d[n]<=degree: g2.remove_node(n)
    return g2

# %%
d=net.degree(g)
d
# Out:
# {'maly_na': 1,
#  'koradokosta': 1,
#  'reinkarni': 2,
#  'cartoonka': 1,
#  'prihodi_smotri': 1,
#  'pgrigas': 2,
#  'riendespe': 1,
#  'musechka': 1,
#  'chijulia': 1,
#  'blga': 1,
#  'gogokostik': 1,
#  'hieroglyph_elle': 1,
#  'demettry': 1,
#  'nata_f_e_ya': 4,
#  'saburay': 1,
#  'idealsummer': 1,
#  'esta_midea': 1,
#  'sarodgini': 3,
#  'cedov_cergey': 1,
#  'kharkov_toronto': 1,
#  'money4you': 6,
#  'sushka_gim': 1,
#  'slayerovich': 2,
#  'azzy_kikoz': 1,
#  'guiness_2010': 2,
#  'indeezzz': 1,
#  'a_philatov': 1,
#  'anfatransf': 1,
#  'podarokua': 1,
#  'stepnoy_lis': 1,
#  'murik_555': 1,
#  'osunsion': 1,
#  'sakura_nu': 2,
#  'broshko': 2,
#  'ihavesage': 1,
#  'von_tageslicht': 1,
#  'gypsymelody': 1,
#  'iron_marg': 1,
#  'dionte_zicarel': 1,
#  'lovesexandmoney': 1,
#  'izmest': 1,
#  'asmi_u': 1,
#  'ivar59': 2,
#  'poupee_russe': 1,
#  'lilya_p': 1,
#  'liana_23b': 1,
#  'kipriena': 1,
#  'azuresky2006': 2,
#  '_ghost_pulse_': 1,
#  'mary_tudor': 1,
#  'vivisin': 5,
#  'zakazfromusa': 1,
#  'atom_golany': 2,
#  'valja_vorobjoff': 1,
#  'notolya': 1,
#  'nashlykid': 1,
#  'monsenor': 1,
#  'xerasse': 1,
#  'no_lullaby': 1,
#  'petr26': 2,
#  'viesel': 1,
#  'elenushka': 1,
#  'busrra': 1,
#  'novoromantik': 1,
#  'zaleph': 5,
#  'zosuspend_mnu': 1,
#  'ajgul': 2,
#  'schenkh': 1,
#  'a_nagayna': 1,
#  'vladimirgin': 4,
#  'luda_berlin': 3,
#  'p_n_z_8_8': 1,
#  'darth_bender': 1,
#  'popov_sergey_ru': 1,
#  'pantufly': 1,
#  'me_galka': 1,
#  'neo_neon': 1,
#  'andreism': 1,
#  'xalal4ullag': 3,
#  'maneulv': 1,
#  '_vopros': 1,
#  'nadeyka_sh': 2,
#  'mphedoseeva': 2,
#  'wilmore23': 1,
#  'zapis_segodny': 2,
#  'remochka': 2,
#  'grazgdanin': 1,
#  'ffoo': 1,
#  '274': 1,
#  'elvingamarie': 1,
#  'beardedguru': 3,
#  'pani_ga': 1,
#  'eva_nadu': 1,
#  'sointransigente': 1,
#  'designer_plya': 1,
#  'slivka20': 1,
#  'humanitarium': 1,
#  'shakariazia': 2,
#  'suvorow_': 1,
#  'ungelt': 2,
#  'colt_browning': 1,
#  'elve': 1,
#  'pawet': 1,
#  'wild_wild_ash': 1,
#  'clementine_mil': 2,
#  'qbeth': 1,
#  'vladon': 1,
#  'urd_norman': 1,
#  'olmeka': 7,
#  'ehecate': 3,
#  'verticaltreck': 4,
#  'amaliaehnsh': 3,
#  'zanoza_j': 1,
#  'bumbiere': 3,
#  'amnuel': 3,
#  'tat_carera': 1,
#  'jrc4558': 3,
#  'ezhan': 1,
#  'besttoday': 2,
#  'evangellin': 1,
#  'suntin': 1,
#  'noizzzefixxxion': 1,
#  'lakschmi': 1,
#  'bashstalk': 1,
#  'musin_rustam': 1,
#  'yulce': 1,
#  'seiv': 1,
#  'negodniki': 1,
#  'nunya_n': 1,
#  'zeffiroso': 1,
#  'leanezoo': 1,
#  'kohanna': 2,
#  'kelonjk': 1,
#  'sunbeam_': 1,
#  'valorieqs': 1,
#  'dorygrey': 2,
#  'gabbear': 1,
#  'malsinc': 2,
#  'samadama': 1,
#  'solvita': 1,
#  'tulo_spinwolf': 1,
#  'allenzet': 1,
#  'vovalcano': 1,
#  'werton': 1,
#  'romacha': 1,
#  'slonikoff_net': 1,
#  'chtez': 1,
#  'frau_mia': 2,
#  'lyamba': 1,
#  'ftvn_2010': 1,
#  'nata_shi': 2,
#  'ap_ata': 2,
#  'dulcinea_nata': 1,
#  'shaulreznik': 9,
#  'pisankov': 1,
#  'defrostik': 1,
#  'alexizm': 2,
#  'mass_media_ua': 1,
#  'elentin': 2,
#  'adesty': 1,
#  'catch_': 1,
#  'shtabss': 3,
#  'a_n_c_o_r': 1,
#  'miranduht': 1,
#  'sterk': 1,
#  'yanoos': 1,
#  'battisto': 1,
#  'launch4you': 1,
#  'freken_sniff': 1,
#  'fleur_de_cassie': 1,
#  'eltheriol_jew': 4,
#  'montagnard': 1,
#  'tofu_russia': 1,
#  'esliseksa_net': 1,
#  'dilanbim': 2,
#  'vesna_1965': 1,
#  'gulnaz': 2,
#  'ur_sun': 2,
#  'unab0mber': 1,
#  'lolyes': 1,
#  'alipchik': 2,
#  'valeks': 2,
#  'irkku777': 1,
#  'cannibal': 3,
#  'rimma_bbusia': 1,
#  'trequarta': 1,
#  'dr_divisenko': 1,
#  'hnyamohnya': 1,
#  'savenkov': 2,
#  'kitten_z': 1,
#  'auth_r': 8,
#  'high_on_toes': 1,
#  'norapotapova': 1,
#  'goshmarik': 1,
#  'serapion82': 1,
#  'koro4ka': 2,
#  'taksus': 1,
#  'rustamchik': 1,
#  'loktev': 1,
#  'contessa7': 2,
#  'lusiaparty': 1,
#  'kuk_ua': 1,
#  'orechiv': 1,
#  'coffeetale': 2,
#  'snorkelstein': 3,
#  'abeliakov': 1,
#  'valitova': 1,
#  'bent_insomnia_m': 1,
#  'kolenki': 1,
#  '_nikolay': 2,
#  'ladyanechka': 1,
#  'keen_on_you': 1,
#  'nu_ance': 1,
#  'redkvoevoe': 1,
#  'chr0matin': 1,
#  'punk72': 1,
#  'aquafea': 2,
#  'jia_dragon': 1,
#  '_odinn_': 1,
#  'turbeeyon': 4,
#  'borzova_daria': 1,
#  'crazy_wind': 2,
#  'wutka': 3,
#  'tsaritsa_makosh': 1,
#  'cazadora_2': 1,
#  'yolka13': 2,
#  'svetlana_tx': 1,
#  'theredone': 1,
#  'lizard__queen': 4,
#  'gerdaxxi': 1,
#  'alcedorussicus': 1,
#  'artmotion': 2,
#  'kaizer_tg': 1,
#  'mulya_diana': 2,
#  'kletki': 1,
#  'mari_anna': 2,
#  'k_stein': 2,
#  'gourry_aka_pm': 1,
#  'point_666': 3,
#  'dazdraperma_k': 2,
#  'andrelet': 1,
#  'grassface': 1,
#  'eva360': 3,
#  'lucky_delf': 2,
#  'marizelsu': 1,
#  'ajojo': 1,
#  'kengako': 1,
#  'i_chin': 1,
#  'yukinochka': 1,
#  'dmitin': 1,
#  'forrary': 2,
#  '_diesel_': 1,
#  'boddah_caster': 1,
#  'im_spring': 1,
#  'mariamz': 4,
#  'x_style': 1,
#  'trimfaktor': 1,
#  'lib_ry': 1,
#  'olya_lya_': 2,
#  'blog_nexta': 1,
#  'jntra': 1,
#  'lunika': 1,
#  'ikar_2': 2,
#  'tasilda': 3,
#  'daritta': 5,
#  'absolut_': 1,
#  'darina29': 1,
#  'izluchatel': 1,
#  'lyuniso': 2,
#  'studio_maneken': 1,
#  'seioneira': 1,
#  'mira_a': 1,
#  'palsmarties': 1,
#  'deva_m': 1,
#  'fortochka': 8,
#  'nilkin': 1,
#  '__dobriy_t__': 2,
#  'konsumterra': 1,
#  'miss_grace': 4,
#  'delfin_1975': 1,
#  'lite_lite_lite': 1,
#  'red_valjok': 1,
#  'grenzlos': 1,
#  '_ina_ya_': 1,
#  'lthdbi': 1,
#  'tanyastakhanova': 3,
#  'swechka': 6,
#  'gran_aventura': 1,
#  'medve_ed': 1,
#  'twilight_g': 1,
#  'kamenskii': 1,
#  'tom_i_lina': 4,
#  'otverzhennaia': 1,
#  'bsng': 1,
#  'lucky_aka_vera': 1,
#  'dzokonda': 2,
#  'anndii': 1,
#  '_lama': 1,
#  'pg_bardin': 3,
#  'don_sever': 2,
#  'bytmojet': 1,
#  'anatoliypost': 1,
#  'kakaschenko': 2,
#  'neverland333': 1,
#  'trunes': 1,
#  'geenevra': 1,
#  'angelita24': 1,
#  'lolapokakala': 1,
#  'svetlaya_lesya': 1,
#  'lubard_on_line': 1,
#  'zorraestelar': 1,
#  'tendress': 1,
#  'catharsis_way': 1,
#  'rabarbar': 1,
#  'didebuli': 1,
#  'deodan': 1,
#  'yusuper': 1,
#  'ljucia': 3,
#  'iren_rose': 3,
#  'kapelsin': 1,
#  'plucer': 3,
#  'nadyaruss': 1,
#  'lady_ester': 1,
#  'antivit': 2,
#  'puma_blanca': 1,
#  'babira': 1,
#  'supercoupon': 1,
#  'hitlerolog': 1,
#  'reallaer': 1,
#  'chudonapalochke': 1,
#  'expert_online': 2,
#  'oleg_dunaev': 2,
#  'daria_colada': 1,
#  'star_veselchak': 1,
#  'cat_ty': 1,
#  'timofeyeva': 1,
#  'fishunia': 2,
#  'borzh': 1,
#  'garciajeans_ukr': 1,
#  'carpenco': 1,
#  'belleelle': 1,
#  'gingerella': 5,
#  'goooseberry': 3,
#  'tatiana_siver': 1,
#  'underworld14': 1,
#  'trayma': 1,
#  'blckwngedroses': 1,
#  'dowload_here': 1,
#  'nimuravka': 6,
#  'fif': 14,
#  'zvezdo4kaman9': 1,
#  'realya': 1,
#  'marina_z_s': 2,
#  'bambookin': 1,
#  'tsiana': 2,
#  'alyona_l': 1,
#  'elena_mihno': 1,
#  'minimaldeep': 1,
#  'isida': 1,
#  'my_sex_dnevnik': 1,
#  'treatment_child': 1,
#  'tokuiayasu': 1,
#  'kapirk': 1,
#  '13mayapple13': 1,
#  'cars_drive': 5,
#  'miayyy': 1,
#  'schastje_moe': 1,
#  'scindapsus': 1,
#  'resnicy': 1,
#  'bublik64': 6,
#  'le_taxidermiste': 1,
#  'strizhkov': 1,
#  'aleks_ter': 2,
#  'mamkadoctor': 4,
#  'bnnnnd_spb': 1,
#  'sova': 2,
#  'serdcem_i_duwoj': 1,
#  'musyavaya': 1,
#  'maupiti': 2,
#  '__kisa': 1,
#  'nt4friends': 1,
#  'lenavoronova': 1,
#  'dama_s_kamnyami': 1,
#  'free_emotion': 1,
#  'kerberusha': 2,
#  'kurrguzova': 1,
#  'sad2007': 1,
#  'fasol_bobovay': 1,
#  '04manska9': 1,
#  '_bbw': 4,
#  'spawn_garret': 1,
#  '_evo': 1,
#  'ezhi_mil': 1,
#  'femme_exotique': 1,
#  'scepticist': 1,
#  '_superv_': 1,
#  'khairullina': 1,
#  'donnna_rosa': 2,
#  'nadorich': 1,
#  'red_ashberry': 2,
#  'langusta': 1,
#  'more_vnutri': 1,
#  'dina_empire': 1,
#  'un_reve': 4,
#  'matv2hoda': 2,
#  'isya': 1,
#  'dasha_kiev': 1,
#  'cn_mangetsu': 1,
#  'mrkaterin': 1,
#  'nika_smile': 1,
#  'shushencija': 1,
#  'luwyt': 1,
#  'nesya': 2,
#  'holiday_n': 1,
#  'allaq': 3,
#  'pepsiman6': 1,
#  'la_cappadocia': 3,
#  'svvallovv': 1,
#  'in_dee': 1,
#  'nagikcko': 1,
#  'katrin_84': 1,
#  'edodolev': 2,
#  'chekesha': 2,
#  'thecode': 2,
#  'avaku': 1,
#  'avaks': 1,
#  'und333': 2,
#  're_diez': 1,
#  '_snusmumrik': 3,
#  'rinamari': 2,
#  'fess_84': 1,
#  'igor_sizov': 1,
#  '1kino': 2,
#  'mazul': 1,
#  'holly_inna': 1,
#  'tany_06': 1,
#  'vladoga': 1,
#  'd_r_i_v_e': 1,
#  'anna_move': 9,
#  'atasss': 1,
#  'poignant_art': 1,
#  'abramovv': 3,
#  'stasiaa': 2,
#  'lake_spirit': 2,
#  'kozlevski': 2,
#  'my_flickr_faves': 1,
#  'dorenko': 1,
#  'olga_myakota': 1,
#  'vetaliano': 1,
#  'graf_vk': 1,
#  'natalia1974': 1,
#  'fkusno': 1,
#  'vg36': 2,
#  'pustota1': 1,
#  'jinjer_flover': 2,
#  'serg_stepan': 1,
#  'slaneyder': 1,
#  'tashal': 1,
#  'lemur_lori': 5,
#  'kolzina': 1,
#  'i_crust': 14,
#  'penguin_lolo': 1,
#  'anfisiy': 1,
#  'loralains': 7,
#  'tatzay': 1,
#  'nasekomof': 3,
#  'asukachev': 1,
#  'chumak2005': 1,
#  'illeniya': 2,
#  'ya_puchu_glaz': 1,
#  'iaugen': 1,
#  'panda_684': 3,
#  'slaw_alena': 2,
#  'ne_prosto_mama': 1,
#  'kuh_nja': 1,
#  'ljizka': 1,
#  'aushedg': 1,
#  'cosmophoto': 1,
#  'kris_tall': 3,
#  'asatokenji': 1,
#  'natalya_abramov': 1,
#  'semero_smelyh': 1,
#  'myxamyxa': 1,
#  'tanjas': 1,
#  'nati_nata': 1,
#  'ggpp': 1,
#  'tan_go': 2,
#  'olgatallinn': 1,
#  'abzaz': 1,
#  'whiskyblog': 1,
#  'arsbam': 2,
#  'belorusska': 1,
#  'ladyganesha': 2,
#  'danka_pu': 1,
#  'back_in_me': 1,
#  'deligia': 2,
#  'donvictorio': 1,
#  'malashka': 4,
#  'vati_1978': 1,
#  'palcev': 1,
#  'cherny_bada': 2,
#  'deadshadow': 3,
#  'bridgetjones_ny': 8,
#  'alex_nik': 1,
#  'designghost': 1,
#  'sha_nezhka': 1,
#  'sky_rhymer': 1,
#  'avprokofiev': 1,
#  'your_eithery': 3,
#  'jannatt': 3,
#  'superolga': 1,
#  'anlahel': 1,
#  'alenochkav': 1,
#  'kseniapinto': 1,
#  'morskayaaa': 1,
#  'alena_stepanova': 1,
#  'step05': 1,
#  'vi_1981': 1,
#  'dedpihto': 2,
#  'lis_andra': 1,
#  'azatsh': 1,
#  'dimka_plotnikov': 1,
#  'pal_petrovich': 3,
#  'vgerzane': 1,
#  'lolly_diva': 4,
#  'cccameron': 1,
#  'lollochka': 1,
#  'shansproducer': 1,
#  'krem_brulle': 4,
#  'kvito4ek': 2,
#  'anetak': 2,
#  'kisa_murka': 2,
#  'ditafontiz': 1,
#  'msmolyak': 1,
#  'olenka_vlad': 1,
#  'kf4': 1,
#  'trofimov_sn': 1,
#  'ksu_ipekakuana': 1,
#  'aelita_forget': 1,
#  'vesnushkacat': 1,
#  'dieweiseeule': 2,
#  'dark_seaman': 1,
#  'a1eksan9ra': 1,
#  'vladika_fokina': 1,
#  'nikolaeva_anna': 1,
#  '_tori_': 2,
#  'teyli_tei': 1,
#  'sandrixxx': 2,
#  'alexwilf': 1,
#  'ledi_kenleh': 1,
#  'gis_girl': 1,
#  'xmelnikov': 1,
#  'vinzilit': 1,
#  'telemakh': 2,
#  'godosha': 1,
#  'foxly': 2,
#  '011615': 1,
#  'smuke': 1,
#  'polmuaddib': 1,
#  'temik319': 3,
#  'yarosh_ka': 1,
#  'expatka': 1,
#  'musictube_ru': 4,
#  'ksandr10': 2,
#  'terricola': 2,
#  'lunnaya_belka': 2,
#  'shperk': 2,
#  'stoit_v_teni': 1,
#  'tyrichavp': 1,
#  'copperlady': 1,
#  'achtung_com_ua': 1,
#  'fuckeach': 1,
#  'toxa_slag': 1,
#  'novizhdy': 1,
#  'sonceniatko': 2,
#  'svobodnaptichka': 1,
#  'ingunn_helge': 1,
#  'open_air_nu': 2,
#  'allegoria': 1,
#  'talerka_ru': 1,
#  'pjoter_ivanov': 1,
#  'apalikulinda': 1,
#  'musikk': 2,
#  'freedom_consult': 1,
#  'winston_two': 1,
#  'ninapti': 2,
#  'ixci': 1,
#  'emo_chaos': 1,
#  'goddamn_russkie': 1,
#  'nutly': 5,
#  'frida_friends': 1,
#  'l_mariam': 3,
#  'hsot': 1,
#  'supremsokol': 1,
#  'boevoi_zayats': 1,
#  'vika_dika': 1,
#  'diabelek': 8,
#  'teatr_vkusa': 1,
#  'vgo': 1,
#  'boberrulit': 1,
#  'in_opposition': 1,
#  'chimaerandi': 1,
#  'f1ct1_on': 1,
#  'bj_ba': 1,
#  'moe_imya_lisa': 1,
#  'bonafiden': 8,
#  'krasota007': 1,
#  'talentjr': 1,
#  'mumms': 1,
#  'fra_dominic': 1,
#  'mitek_mitekych': 1,
#  'zhevtun': 1,
#  'margo_na': 1,
#  'oprion': 1,
#  '1satana': 3,
#  'echidnaa_lavisi': 3,
#  'besheniy67': 1,
#  'hot_dognitsa': 1,
#  'volkar': 1,
#  'ohnegrenzen': 1,
#  'valeria_st': 4,
#  'denius': 1,
#  'seo4nik': 1,
#  'mr_quietest': 8,
#  'tokio_paris': 1,
#  'ne_napokaz': 1,
#  'oxania': 1,
#  'i_beauty': 1,
#  'arkady1': 1,
#  'kinoistoriya': 1,
#  'krechetova': 2,
#  'lc_players': 1,
#  'deniszheleznyy': 1,
#  'robinzon_girl': 1,
#  'amfibol': 1,
#  'b00t': 1,
#  'yabloki_tybloki': 1,
#  'bzdyshek': 1,
#  'rebekkka': 2,
#  'mkoenig': 2,
#  'exjt': 1,
#  'quaeritans': 1,
#  'asiyath': 1,
#  'radegost': 2,
#  'garret_lab': 1,
#  'barolya': 1,
#  'gazirovannaja': 3,
#  '0ffline': 1,
#  'mellot': 1,
#  'saul_paradise': 4,
#  'charunga': 1,
#  'iron_ksu': 2,
#  'droanton': 1,
#  'krestiknolik': 1,
#  'credo_always': 1,
#  'stefanel_lora': 1,
#  'nahalenok': 1,
#  'shurikdc': 1,
#  'alfalfalfa': 1,
#  'fobious': 1,
#  'senmurv': 1,
#  'lenochka11': 1,
#  'matilda_ussr': 1,
#  'ann_orlova': 1,
#  'vechnaia_zima': 1,
#  'otello': 1,
#  'ersil': 2,
#  'mobis33': 1,
#  'kumiko_artistka': 1,
#  'domkratov': 1,
#  'temptee': 4,
#  'aintlion': 2,
#  'deatravel': 1,
#  'i_n_n': 2,
#  'simcha_eichel': 1,
#  'likeladygodiva': 1,
#  'skras': 1,
#  'korolka': 2,
#  'irena_iris': 4,
#  'orleanz': 4,
#  'maminbluz': 1,
#  'indig0z': 3,
#  'aksuk': 1,
#  'sunleoka': 1,
#  'tigra_katy': 2,
#  'rock_f': 1,
#  'dushegubik': 1,
#  'shpion14': 1,
#  'radostev_v': 1,
#  'moerta': 2,
#  'veryloving': 1,
#  'bulfriend': 3,
#  'screechowl_uhu': 2,
#  'jewelin': 1,
#  'upiachka': 1,
#  '_tankist': 1,
#  'marineval': 1,
#  'okhalatnikova': 1,
#  'ajushka': 1,
#  'stobla': 1,
#  'xujasse': 1,
#  'shtykh': 1,
#  'aprel': 1,
#  'dr_vodka': 1,
#  'stichelmeister': 2,
#  'young_pickup': 1,
#  'anirinka': 7,
#  'polit_mudak': 1,
#  '6atenka': 1,
#  'technograf': 1,
#  'kosterina': 2,
#  'puchs': 1,
#  'awyr': 1,
#  'lentochka_ts': 1,
#  'towerkeeper': 1,
#  'monusya': 1,
#  'twaneq': 1,
#  'blueray': 1,
#  'f_lia': 1,
#  'peggy_s': 4,
#  'bulinat': 1,
#  'fucktohell': 2,
#  'arctickfox1911': 1,
#  'carmmen': 1,
#  'avotiya': 3,
#  'flying_bee2': 1,
#  'maxteror': 1,
#  'mclaren2000': 1,
#  'ys_pumpui': 1,
#  'pampulus': 4,
#  'kizhajla': 1,
#  'rudenko_s': 1,
#  'straytrain': 1,
#  'thebestya': 3,
#  'konoza': 1,
#  'yama_nov': 1,
#  'spleza': 1,
#  'madamchic': 1,
#  'anegra': 2,
#  'de_kor': 1,
#  'lugerr': 1,
#  'igor_mkrt': 12,
#  'cheshire_pig': 7,
#  'kucha_mala': 7,
#  'minimum_riska': 1,
#  'nishtyak': 1,
#  'nadiki': 1,
#  'its_funky': 1,
#  'apo_monitor': 1,
#  'moon_abbys': 1,
#  '_gromova_': 1,
#  'trivee': 1,
#  'webdevel': 1,
#  'immoralist': 26,
#  'n0vikova': 3,
#  'charliesies': 3,
#  'spy_read': 1,
#  'zelda_cat': 1,
#  'tolstiy': 2,
#  'bella_choo': 1,
#  'sprvyta': 1,
#  'lavictoria': 1,
#  'ponka_kiev': 1,
#  'rabauken': 2,
#  'almog': 1,
#  'starayakniga': 3,
#  'yoko_squaw': 1,
#  'atomy': 1,
#  'vidimopanda': 1,
#  'iry': 2,
#  'sasha_voropaev': 1,
#  'mikeorl': 4,
#  'oldbore': 1,
#  'lenusch11': 2,
#  'freeraser': 1,
#  'irr': 2,
#  'bezlepkina': 6,
#  'posovetui': 2,
#  'segodnya': 4,
#  'laoshe': 2,
#  'akm_akm': 1,
#  'hina_chleck': 1,
#  'x_polkovnik': 1,
#  'jinjerd': 3,
#  'violin_fox': 1,
#  'ivan_rosa': 1,
#  'yzhka': 1,
#  'shelter_a': 1,
#  'koza_nostra': 1,
#  'bodraschy_lesch': 1,
#  'zubnik_fabrique': 1,
#  'estlona': 1,
#  'rttv': 1,
#  'zajchevskij': 1,
#  's0n1c': 1,
#  'klotti': 2,
#  'blanqi': 2,
#  'squo': 1,
#  'sun_day': 1,
#  'munakokkelli': 1,
#  'mlledefer': 1,
#  'nikesha': 1,
#  'ggmarketing': 1,
#  'ada_samarka': 2,
#  'mina_und_otto': 1,
#  'loftetagi': 1,
#  'nob239': 1,
#  'citywoman': 2,
#  'lucysd': 1,
#  'm_ul_s': 1,
#  'winniepooh_i_k': 3,
#  'soljarka': 1,
#  'pro4off': 1,
#  'sky_thunder': 1,
#  'viaceslavut': 1,
#  'natasha_kob': 1,
#  'japshum': 1,
#  'lark_dis': 2,
#  'a_bl': 1,
#  'moravit': 1,
#  'denisuy': 1,
#  'voi_voi': 1,
#  'u_l_i_n_k_a': 2,
#  'iris_k': 1,
#  'life_and_islam': 3,
#  'ce_man': 1,
#  'chelovek': 1,
#  'kino_bez_graniz': 1,
#  'esperance1': 1,
#  'erstebankua': 1,
#  'finnmo': 2,
#  'garfield_y': 5,
#  'bothman': 1,
#  'karrykarry': 1,
#  'bod_hi': 1,
#  'dzyubochka': 2,
#  'yahoo_zloi': 1,
#  'nettless': 3,
#  'organs_pusher': 2,
#  'garfield_s': 3,
#  'x_line': 1,
#  'leynell': 1,
#  'furzicle': 1,
#  'izummmm': 2,
#  'vlodamir': 1,
#  'new_azzia': 1,
#  'virgofelix': 1,
#  'si_matro': 1,
#  'lledanni': 3,
#  'mmontecarlo': 1,
#  'basque': 3,
#  'deferre': 6,
#  'grimmy3d': 1,
#  'ice_nugget': 1,
#  'yuliaskrap': 1,
#  'kekoza': 1,
#  'odri_hepbern': 1,
#  'onikuz': 1,
#  'dimqa': 1,
#  'totsvet': 2,
#  'strongholder': 1,
#  'voblic': 3,
#  'ieiesj': 1,
#  'fashuggah': 1,
#  'a_galaxy': 2,
#  'elenavi': 1,
#  'vova_chuma': 1,
#  'lana_kou': 3,
#  'frr': 2,
#  'visnushko': 1,
#  'noger_vruker': 1,
#  'detenish': 4,
#  'tutux': 1,
#  'art_gudkof': 1,
#  '_yana': 1,
#  'naife': 1,
#  '__cara__': 1,
#  'vi_laschenov': 1,
#  'fruto': 1,
#  'kvakshi': 4,
#  'regul': 2,
#  'wwwnastenawww': 1,
#  'mahaon_ysh': 1,
#  'ryzhaya_zluchka': 2,
#  'ivkoshkin': 1,
#  'perlovka_blog': 2,
#  '_jilly_': 1,
#  'janataha': 2,
#  'kondratti': 2,
#  'masam_3': 1,
#  'kala_hansa': 1,
#  'busyana': 1,
#  'kapitoshik': 2,
#  'jeol': 7,
#  'tazmaniand_evil': 1,
#  'novi_9': 2,
#  'rina_grant': 1,
#  'lomenille': 1,
#  'sergei_anufriev': 1,
#  'string_fever': 1,
#  'akusti4ka87': 1,
#  'zvetok_sakuri': 1,
#  'brilly23': 1,
#  'molcaxitl': 1,
#  'kikimora_b': 6,
#  'azbonfad': 1,
#  'zakata': 3,
#  'oustinov': 1,
#  'inessa_b': 4,
#  'intaf': 3,
#  'br_andr': 1,
#  'assolata': 2,
#  'igorsadkof': 1,
#  'belov_artstudio': 1,
#  'kidw': 1,
#  'm_paramonov': 1,
#  'poddubnyy59': 1,
#  'vitbel2000': 1,
#  'reydan': 1648,
#  'damirs': 1,
#  'hydrargirum': 1,
#  'ioscat': 1,
#  'groats': 6,
#  'inessa_v': 3,
#  'a_vysotskiy': 1,
#  '_agorafobia_': 1,
#  'rmorga': 1,
#  'nasuto_procione': 1,
#  'shupaka': 2,
#  'bombey': 2,
#  'zalmax': 2,
#  'free_elefant': 2,
#  'willy_sever': 1,
#  'mfermin': 1,
#  'shiros': 11,
#  'arhangelsky': 1,
#  'gobuz': 2,
#  'haxah': 1,
#  'ta_shenka': 1,
#  'swiss_wife': 2,
#  'slayter': 1,
#  'mishka_kaola': 2,
#  'vitavini': 2,
#  'kipzt': 1,
#  'all_abaut': 2,
#  'n_e': 1,
#  'igornem': 1,
#  'anaeill_nitting': 1,
#  'foshizd': 1,
#  'kot1972': 1,
#  'oygenn': 1,
#  'alien_u2': 1,
#  'biancoloto': 1,
#  'lollip0pa': 3,
#  'aentelis': 3,
#  'principall': 1,
#  'milewska': 1,
#  'ice_skws': 1,
#  'tejido': 1,
#  'discreet_chaos': 1,
#  'aaafnbn': 1,
#  'djtonik': 1,
#  'zench': 2,
#  'yellowsmoke1': 2,
#  'scaramel': 1,
#  'evjenia': 1,
#  'valenok8': 1,
#  'pepe_47': 1,
#  'n_a_d_i': 1,
#  'krootee': 1,
#  'nakkiga': 1,
#  'devochk0': 1,
#  'true_sergio': 1,
#  'fiquet': 1,
#  'chek_100': 3,
#  'zhukola': 1,
#  'guruken': 1,
#  'ph_b': 4,
#  'baby_malishka': 1,
#  'mm_jam': 2,
#  '81les': 1,
#  '0l0': 3,
#  'socialism_vk': 2,
#  'vladfe': 4,
#  'keiretbe': 1,
#  'kolchakark': 1,
#  'kussike': 1,
#  'boziya_korovka': 1,
#  'bazjak': 1,
#  'georgich': 1,
#  'shnaps': 1,
#  'v_olga_dnepr': 2,
#  'indrik_book': 1,
#  'gorbarsky': 1,
#  '2keys': 1,
#  'morgulis': 4,
#  'lepeztok': 2,
#  'irishka51254': 1,
#  'liilaa': 2,
#  'solga77': 2,
#  ...}

# %%
for i in range(1,10):
    core = trim_degrees(g, degree=i) 
len(core)
# Out:
# 770

# %%
type(core)
# Out:
# networkx.classes.multigraph.MultiGraph

# %%
c=net.closeness_centrality(core)

# %%
cs=sorted_map(c)
cs[:10]
# Out:
# [('azbukivedi', 0.6117740652346858),
#  ('valerois', 0.5879204892966361),
#  ('bagira', 0.580377358490566),
#  ('kpoxa_e', 0.5675276752767527),
#  ('karial', 0.565025716385011),
#  ('kirulya', 0.5366364270760642),
#  ('borisakunin', 0.5292498279421886),
#  ('yelya', 0.5227736233854521),
#  ('angerona', 0.5213559322033898),
#  ('snorapp', 0.5210027100271003)]

# %%
#Betweenness Centrality

# %%
b=net.betweenness_centrality(core)
bs=sorted_map(b)
bs[:10]
# Out:
# [('valerois', 0.16695738080654984),
#  ('azbukivedi', 0.09801168103385016),
#  ('bagira', 0.06282469913200113),
#  ('karial', 0.051282628756619236),
#  ('kpoxa_e', 0.04411630040052614),
#  ('kirulya', 0.02786254802919023),
#  ('snorapp', 0.026582022759573002),
#  ('borisakunin', 0.026291115481229255),
#  ('gracebirkin', 0.023960779997234286),
#  ('eprst2000', 0.021644134004097388)]

# %%
names1=[x[0] for x in ds[:10]]
names2=[x[0] for x in cs[:10]]
names3=[x[0] for x in bs[:10]]

# %%
## use Python sets to compute a union of the sets
names=list(set(names1) | set(names2) | set (names3))

# %%
table=[[name,d[name],c[name],b[name]] for name in names]
table
# Out:
# [['yelya', 582, 0.5227736233854521, 0.01444789051185748],
#  ['gracebirkin', 2575, 0.5022860875244938, 0.023960779997234286],
#  ['samoleg', 2597, 0.4604790419161677, 0.015046002474947154],
#  ['masha_koroleva', 2683, 0.4945337620578778, 0.019108734369004593],
#  ['kpoxa_e', 946, 0.5675276752767527, 0.04411630040052614],
#  ['cheger', 2887, 0.3903553299492386, 0.0009638305146620796],
#  ['zina_korzina', 2596, 0.47972551466001245, 0.009946394073282934],
#  ['snorapp', 2707, 0.5210027100271003, 0.026582022759573002],
#  ['elladkin', 2616, 0.456379821958457, 0.018649024983887926],
#  ['karial', 2717, 0.565025716385011, 0.051282628756619236],
#  ['tareeva', 2970, 0.47235872235872234, 0.008534920883779136],
#  ['angerona', 752, 0.5213559322033898, 0.019653087424363894],
#  ['bagira', 1481, 0.580377358490566, 0.06282469913200113],
#  ['borisakunin', 4691, 0.5292498279421886, 0.026291115481229255],
#  ['valerois', 232, 0.5879204892966361, 0.16695738080654984],
#  ['eprst2000', 2510, 0.5168010752688172, 0.021644134004097388],
#  ['doctor_liza', 3046, 0.47293972939729395, 0.02132678583761749],
#  ['azbukivedi', 2541, 0.6117740652346858, 0.09801168103385016],
#  ['kirulya', 2398, 0.5366364270760642, 0.02786254802919023]]

# %%
net.closeness_centrality(g)
# Out:
# {'maly_na': 0.26346399485446653,
#  'koradokosta': 0.25608972195235064,
#  'reinkarni': 0.26746185750940343,
#  'cartoonka': 0.26346399485446653,
#  'prihodi_smotri': 0.25205037020773813,
#  'pgrigas': 0.2767200449100372,
#  'riendespe': 0.26330497554027177,
#  'musechka': 0.2565422704177644,
#  'chijulia': 0.26652960727290503,
#  'blga': 0.25182266862931857,
#  'gogokostik': 0.2536013254272759,
#  'hieroglyph_elle': 0.26832306159353436,
#  'rmorga': 0.2598924077780955,
#  'nasuto_procione': 0.26330497554027177,
#  'shupaka': 0.26834947036895784,
#  'bombey': 0.27399656440484754,
#  'zalmax': 0.2609706124280266,
#  'free_elefant': 0.2707435369906627,
#  'willy_sever': 0.2598761515847414,
#  'mfermin': 0.2582829096162272,
#  'shiros': 0.2737498352775808,
#  'arhangelsky': 0.2598761515847414,
#  'gobuz': 0.2574392687165657,
#  'haxah': 0.25745218268839226,
#  'ta_shenka': 0.259681235769454,
#  'swiss_wife': 0.25215672334116546,
#  'slayter': 0.264189964602681,
#  'mishka_kaola': 0.26251195985100584,
#  'vitavini': 0.26184466806118684,
#  'kipzt': 0.2512895839633646,
#  'all_abaut': 0.27599962039731746,
#  'n_e': 0.2551677546150067,
#  'igornem': 0.2598924077780955,
#  'anaeill_nitting': 0.2525303980619336,
#  'foshizd': 0.2538064125761428,
#  'kot1972': 0.26415237149483195,
#  'oygenn': 0.25239160054268434,
#  'alien_u2': 0.2560483870967742,
#  'biancoloto': 0.25196375145837424,
#  'lollip0pa': 0.2818174770828892,
#  'aentelis': 0.27895667409493907,
#  'principall': 0.2554912956265831,
#  'milewska': 0.26330497554027177,
#  'ice_skws': 0.2535630005928647,
#  'tejido': 0.2536013254272759,
#  'discreet_chaos': 0.25731854779249125,
#  'aaafnbn': 0.2519091903877858,
#  'djtonik': 0.27292178237952985,
#  'zench': 0.2652832253945088,
#  'yellowsmoke1': 0.260700807658865,
#  'scaramel': 0.26519130466498886,
#  'evjenia': 0.2538064125761428,
#  'valenok8': 0.25143804034582135,
#  'pepe_47': 0.2608793153969896,
#  'n_a_d_i': 0.2551677546150067,
#  'krootee': 0.264189964602681,
#  'nakkiga': 0.26346399485446653,
#  'devochk0': 0.2650640110340805,
#  'true_sergio': 0.2541961047096013,
#  'fiquet': 0.2598761515847414,
#  'chek_100': 0.2798648934737004,
#  'zhukola': 0.255058101293576,
#  'guruken': 0.26832306159353436,
#  'ph_b': 0.28168281989526767,
#  'baby_malishka': 0.25140036651568065,
#  'mm_jam': 0.27241986549017405,
#  '81les': 0.27292178237952985,
#  '0l0': 0.28734829647438537,
#  'socialism_vk': 0.2641275818956253,
#  'vladfe': 0.2887251933405474,
#  'keiretbe': 0.253803459329893,
#  'kolchakark': 0.2702956402130171,
#  'kussike': 0.251843748286144,
#  'boziya_korovka': 0.2641859648272855,
#  'bazjak': 0.25106903398463354,
#  'georgich': 0.2543065004109757,
#  'shnaps': 0.2629328270499955,
#  'v_olga_dnepr': 0.26824963951139574,
#  'indrik_book': 0.2535630005928647,
#  'gorbarsky': 0.2536013254272759,
#  '2keys': 0.26832306159353436,
#  'morgulis': 0.2819103563258501,
#  'lepeztok': 0.25531037025548886,
#  'irishka51254': 0.264189964602681,
#  'liilaa': 0.274509495463069,
#  'solga77': 0.25529692323448083,
#  ...}

# %%
eigenvector_centrality(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-bc845d5628f7> in <module>()
# ----> 1 eigenvector_centrality(g)
#
# NameError: name 'eigenvector_centrality' is not defined
