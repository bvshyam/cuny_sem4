# %%
import nltk

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1d17e602afd> in <module>()
# ----> 1 text1
#
# NameError: name 'text1' is not defined

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text3.concordance("lived")
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
text3.similar("lived")
# Out:
# went took dwelt builded

# %%
text3.common_contexts(["lived"])
# Out:
# adam_an adam_were seth_an seth_after enos_ninety enos_after
# cainan_seventy cainan_after mahalaleel_sixty mahalaleel_after jared_an
# jared_after enoch_sixty methuselah_an methuselah_after lamech_an
# lamech_after noah_after shem_after arphaxad_five

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
text4.concordance('duties')
# Out:
# Displaying 25 of 92 matches:
#  from nature and unpracticed in the duties of civil administration ) ought to
# inies of this country and of my own duties toward it , founded on a knowledge
# zens : Called upon to undertake the duties of the first executive office of ou
# low - citizens , on the exercise of duties which comprehend everything dear an
# be found inseparable from our moral duties , and history bears witness to the
# o whom they confide the legislative duties . It is due to the zeal and wisdom
# lsehood and defamation , but public duties more urgent press on the time of pu
# strength . I shall now enter on the duties to which my fellow citizens have ag
# of my country to the station to the duties of which I am about to pledge mysel
#  from my own inadequacy to its high duties . If I do not sink under the weight
# l endeavors to discharge my arduous duties have been favorably estimated , and
# and of the nature and extent of its duties , with the proper discharge of whic
# ...

# %%
text3.generate('hi')

# %%
len(text2)
# Out:
# 141576

# %%
len(sorted(set(text2)))
# Out:
# 6833

# %%
100*text5.count('lol')/len(text5)
# Out:
# 1.5640968673628082

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent = ['word1', 'word2', 'word3', 'word4', 'word5', 'word6', 'word7', 'word8', 'word9', 'word10']

# %%
sent[1:9] = ['Second', 'Third']

# %%
sent

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done', 'more', 'is', 'said', 'than', 'done']

# %%
set(saying)
# Out:
# {'After', 'all', 'and', 'done', 'is', 'more', 'said', 'than'}

# %%
sorted(set(saying))[-2:]
# Out:
# ['said', 'than']

# %%
fdist1 = FreqDist(text1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a9ccb6c27929> in <module>()
# ----> 1 fdist1 = FreqDist(text1)
#
# NameError: name 'FreqDist' is not defined

# %%
import re

# %%
re.match('abc','abcdef')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-14d30c33c73c> in <module>()
# ----> 1 re.match('abc','abcdef')
#
# NameError: name 're' is not defined

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
[item for item in set(text1) if item.istitle()]
# Out:
# ['Australia',
#  'Ram',
#  'Would',
#  'White',
#  'Darien',
#  'Borneo',
#  'Cross',
#  'Grace',
#  'Sunset',
#  'Alps',
#  'Java',
#  'Blast',
#  'Historically',
#  'Thermes',
#  'Thunder',
#  'Raise',
#  'Clap',
#  'Texel',
#  'Keel',
#  'Brute',
#  'Nicholas',
#  'Pottsfich',
#  'Perhaps',
#  'Decanter',
#  'Sandwich',
#  'Greenlandmen',
#  'Rattler',
#  'Boats',
#  'Roanoke',
#  'Cousin',
#  'Hebrew',
#  'Bedford',
#  'Proceed',
#  'Owen',
#  'Spermacetti',
#  'Consequently',
#  'Walfish',
#  'Maury',
#  'Sachem',
#  'Nelson',
#  'Christian',
#  'Hartz',
#  'Philistines',
#  'Italian',
#  'P',
#  'Jeroboam',
#  'Preserving',
#  'Michael',
#  'Laplandish',
#  'Bottom',
#  'Standing',
#  'Availing',
#  'Thine',
#  'Elijah',
#  'Jews',
#  'Pillar',
#  'George',
#  'Sebastian',
#  'Spouter',
#  'Till',
#  'Belubed',
#  'Scandinavian',
#  'Mate',
#  'Rose',
#  'Moving',
#  'Throughout',
#  'Persian',
#  'Dives',
#  'Perry',
#  'Musket',
#  'Supplied',
#  'Dog',
#  'Caryatid',
# ...

# %%
sorted([w for w in set(text7) if '-' in w and 'index' in w])
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
sorted([w for w in set(text7) if w.isalpha()])
# Out:
# ['A',
#  'ABA',
#  'ABORTION',
#  'ACCEPTANCES',
#  'ACCOUNT',
#  'ACQUISITION',
#  'ADRs',
#  'AG',
#  'AGREES',
#  'AIDS',
#  'AMR',
#  'AN',
#  'AND',
#  'APPEARS',
#  'ASLACTON',
#  'ASSETS',
#  'ASSOCIATES',
#  'ASSOCIATION',
#  'Abbey',
#  'Abbot',
#  'About',
#  'Above',
#  'Abrupt',
#  'Absorbed',
#  'Academically',
#  'Acceptance',
#  'According',
#  'Account',
#  'Achievement',
#  'Ackerman',
#  'Acquisition',
#  'Act',
#  'Activity',
#  'Actually',
#  'Ad',
#  'Adam',
#  'Adams',
#  'Adds',
#  'Administration',
#  'Adolph',
#  'Adopting',
#  'Advance',
#  'Advanced',
#  'Advancing',
#  'Advice',
#  'Advocates',
#  'Aerojet',
#  'Aerospace',
#  'Affairs',
#  'Africa',
#  'African',
#  'After',
#  'Again',
#  'Against',
#  'Agency',
#  'Agnew',
#  'Agriculture',
#  'Ailes',
#  'Air',
#  'Airlines',
#  'Airways',
#  'Akerfeldt',
#  'Akio',
#  'Aktiebolaget',
#  'Al',
#  'Ala',
#  'Alan',
#  'Albany',
#  'Albert',
#  'Albuquerque',
#  'Alexander',
#  'Alfred',
#  'All',
# ...

# %%
babelize_shell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2536bec03c48> in <module>()
# ----> 1 babelize_shell
#
# NameError: name 'babelize_shell' is not defined

# %%
set(text2)
# Out:
# {'breast',
#  'declined',
#  'twould',
#  'liking',
#  'principal',
#  'ungraciously',
#  'dejected',
#  'unwelcome',
#  'what',
#  'gladly',
#  'stealing',
#  'blessing',
#  'addresses',
#  'before',
#  'obliging',
#  'detestably',
#  'moment',
#  'disapprove',
#  'so',
#  'answering',
#  'arrangements',
#  'reading',
#  'risk',
#  'degraded',
#  'yearly',
#  'HER',
#  'aptitude',
#  'along',
#  'warrant',
#  'performing',
#  'Ferrars',
#  'Prescriptions',
#  'reproached',
#  'feature',
#  'unintentional',
#  'Dorsetshire',
#  'distant',
#  'consult',
#  'Brandon',
#  'ME',
#  'respectfully',
#  'parlour',
#  'number',
#  'wooded',
#  'Delaford',
#  'borne',
#  'Drury',
#  'solicitations',
#  'innocent',
#  'living',
#  'These',
#  'addressing',
#  'projection',
#  'told',
#  'deeper',
#  'square',
#  'proceeded',
#  'cows',
#  'foundations',
#  'urgent',
#  'hardship',
#  'detain',
#  'feeling',
#  'banditti',
#  'redeem',
#  'persuaded',
#  'landlord',
#  'outstripped',
#  'Had',
# ...

# %%
['Monty', 'Python'] * 20,
# Out:
# (['Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python',
#   'Monty',
#   'Python'],)

# %%
text2.dispersion_plot(['Elinor', 'Marianne', 'Edward', 'Willoughby'])

# %%
text2[141570]
# Out:
# 'between'

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
my_sent = ["plant","a",'tree']

# %%
' '.join(my_sent)
# Out:
# 'plant a tree'

# %%
text9.index('sunset')
# Out:
# 629

# %%
sent1[2][2]
# Out:
# 'h'

# %%
FreqDist(text5)
# Out:
# FreqDist({'now': 79,
#           'im': 128,
#           'left': 17,
#           'with': 152,
#           'this': 86,
#           'gay': 30,
#           'name': 27,
#           ':P': 15,
#           'PART': 1016,
#           'hey': 264,
#           'everyone': 63,
#           'ah': 8,
#           'well': 81,
#           'NICK': 24,
#           ':': 96,
#           'U7': 119,
#           'is': 372,
#           'a': 568,
#           '.': 1268,
#           'ACTION': 346,
#           'gives': 6,
#           'U121': 36,
#           'golf': 2,
#           'clap': 3,
#           ':)': 101,
#           'JOIN': 1021,
#           'hi': 546,
#           'U59': 12,
#           '26': 10,
#           '/': 133,
#           'm': 81,
#           'ky': 2,
#           'women': 7,
#           'that': 274,
#           'are': 178,
#           'nice': 52,
#           'please': 21,
#           'pm': 108,
#           'me': 415,
#           'there': 120,
#           'ya': 100,
#           'go': 73,
# ...

# %%
sent = ['she', 'sells', 'sea', 'shells', 'by','the', 'sea', 'shore']

# %%
[s for s in sent if s.startswith('sh') ]
# Out:
# ['she', 'shells', 'shore']

# %%
sum([len(w) for w in text1])
# Out:
# 999044

# %%
def percent(word, text):
    return text.count(word)/len(text)

# %%
percent('and',text2)
# Out:
# 0.02366220263321467

# %%
FreqDist(text2)
# Out:
# FreqDist({'[': 3,
#           'Sense': 1,
#           'and': 3350,
#           'Sensibility': 1,
#           'by': 737,
#           'Jane': 1,
#           'Austen': 1,
#           '1811': 1,
#           ']': 1,
#           'CHAPTER': 50,
#           '1': 2,
#           'The': 243,
#           'family': 83,
#           'of': 3565,
#           'Dashwood': 252,
#           'had': 969,
#           'long': 100,
#           'been': 440,
#           'settled': 37,
#           'in': 1904,
#           'Sussex': 9,
#           '.': 3975,
#           'Their': 33,
#           'estate': 19,
#           'was': 1846,
#           'large': 26,
#           ',': 9397,
#           'their': 463,
#           'residence': 7,
#           'at': 806,
#           'Norland': 53,
#           'Park': 22,
#           'the': 3861,
#           'centre': 2,
#           'property': 9,
#           'where': 84,
#           'for': 1234,
#           'many': 98,
#           'generations': 1,
#           'they': 428,
# ...

# %%
set(text1)
# Out:
# {'pricked',
#  'breast',
#  'flexions',
#  'ineffable',
#  'socially',
#  'BRIT',
#  'principal',
#  'azimuth',
#  'steeply',
#  'investment',
#  'thump',
#  'sinewing',
#  'pours',
#  'mediums',
#  'undecreasing',
#  'impotent',
#  'authorities',
#  'boat',
#  'uses',
#  'leper',
#  'unwelcome',
#  'what',
#  'circulate',
#  'gladly',
#  'widest',
#  'priest',
#  'thief',
#  'assist',
#  'stealing',
#  'casked',
#  'illustrate',
#  'countersinkers',
#  'tracts',
#  'incarnated',
#  'owest',
#  'blessing',
#  'costume',
#  'transparently',
#  'before',
#  'dreaminess',
#  'mutes',
#  'sweetener',
#  'MCCULLOCH',
#  'eloquently',
#  'moment',
#  'steering',
#  'rocking',
#  'Doesn',
#  'wooden',
#  'ding',
#  'bravadoes',
#  'community',
#  'so',
#  'ALGERINE',
#  'dismember',
#  'risk',
#  'reading',
#  'hits',
#  'braces',
#  'OR',
#  'commander',
#  'VARIOUS',
#  'yearly',
#  'gliding',
#  'Mississippi',
#  'Luff',
#  'Ghent',
#  'saddest',
#  'brigger',
#  'Philistines',
# ...
