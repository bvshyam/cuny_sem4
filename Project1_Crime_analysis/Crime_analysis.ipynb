# %%
import networkx as net
import urllib
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('moreno_crime/out.MORENO_CRIME_CRIME',sep=' ',skiprows=2,header=None,comment='%',names=['From','To','Junk'])
df
# Out:
#       From   To  Junk
# 0        1    1   NaN
# 1        1    2   NaN
# 2        1    3   NaN
# 3        1    4   NaN
# 4        2    5   NaN
# 5        2    6   NaN
# 6        2    7   NaN
# 7        2    8   NaN
# 8        2    9   NaN
# 9        2   10   NaN
# 10       2   11   NaN
# 11       2   12   NaN
# 12       2   13   NaN
# 13       2   14   NaN
# 14       2   15   NaN
# 15       2   16   NaN
# 16       2   17   NaN
# 17       2   18   NaN
# 18       2   19   NaN
# 19       2   20   NaN
# 20       2   21   NaN
# 21       2   22   NaN
# 22       2   23   NaN
# 23       2   24   NaN
# 24       2   25   NaN
# 25       2   26   NaN
# 26       3   27   NaN
# 27       4   24   NaN
# 28       5   19   NaN
# 29       6   28   NaN
# ...    ...  ...   ...
# 1446   815   47   NaN
# 1447   815  547   NaN
# 1448   815  548   NaN
# 1449   815  352   NaN
# 1450   815  549   NaN
# 1451   815  499   NaN
# 1452   815  550   NaN
# 1453   815  551   NaN
# 1454   815  404   NaN
# ...

# %%
c = net.Graph()

# %%
c.add_edge('moreno_crime/out')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9e1612579c22> in <module>()
# ----> 1 c.add_edge('moreno_crime/out')
#
# TypeError: add_edge() missing 1 required positional argument: 'v'
